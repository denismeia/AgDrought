# %%
import pandas as pd
import numpy as np
import pylab as plt
import xuleta as xu
import seaborn as sn

from scipy import stats
from functools import reduce
import os
month_names = pd.date_range(start='2016-01-01', periods=12, freq='MS').strftime('%b')


#for SQL
from sqlalchemy import create_engine
engine = create_engine('postgresql://denis:sinedoom48@localhost:5432/drought')
fout = '/Users/denismariano/pcloud/0NEWPROJ/document/images/'#mac
#fout = '/home/denis/pcloud/0NEWPROJ/document/images/'

# %matplotlib inline

# %%
# %%time
#FROM SQL DATABASE
#interpolate removes NaN
gpp = pd.read_sql("SELECT * FROM consultas_br.gpp_f2_big_sul_crop",engine).pivot_table(index="acquisition",
                   columns="geocodig_m",
                   values="mean").interpolate()
esi = pd.read_sql("SELECT * FROM consultas_br.esi_big_sul_crop",engine).pivot_table(index="acquisition",
                   columns="geocodig_m",
                   values="mean").interpolate()
zprec = pd.read_sql("SELECT * FROM consultas_br.prec_z_big_sul_crop",engine).pivot_table(index="acquisition",
                   columns="geocodig_m",
                   values="mean").interpolate()
mydlstd = pd.read_sql("SELECT * FROM consultas_br.myd_lstd_big_sul_crop",engine).pivot_table(index="acquisition",
                   columns="geocodig_m",
                   values="mean").interpolate()*0.02 - 273.15
modlstd = pd.read_sql("SELECT * FROM consultas_br.mod_lstd_big_sul_crop",engine).pivot_table(index="acquisition",
                   columns="geocodig_m",
                   values="mean").interpolate()*0.02 - 273.15
mydlstn = pd.read_sql("SELECT * FROM consultas_br.myd_lstn_big_sul_crop",engine).pivot_table(index="acquisition",
                   columns="geocodig_m",
                   values="mean").interpolate()*0.02 - 273.15
modlstn = pd.read_sql("SELECT * FROM consultas_br.mod_lstn_big_sul_crop",engine).pivot_table(index="acquisition",
                   columns="geocodig_m",
                   values="mean").interpolate()*0.02 - 273.15


aux = pd.read_sql("SELECT * FROM consultas_br.aux_big_sul_crop",engine)
# Out:
# CPU times: user 11.5 s, sys: 452 ms, total: 11.9 s
# Wall time: 22.2 s

# %%
# %%time
#Files in CSV
datafolder = "../SQL/"
gpp = pd.read_csv(datafolder+"drought_consultas_br_gpp_f2_big_sul.csv").pivot_table(index="acquisition",
                   columns="geocodig_m",
                   values="mean")

esi = pd.read_csv(datafolder+"drought_consultas_br_esi_big_sul_crop.csv").pivot_table(index="acquisition",
                   columns="geocodig_m",
                   values="mean").interpolate()
zprec = pd.read_csv(datafolder+"drought_consultas_br_prec_z_big_sul_crop.csv").pivot_table(index="acquisition",
                   columns="geocodig_m",
                   values="mean").interpolate()
mydlstd = pd.read_csv(datafolder+"drought_consultas_br_myd_lstd_big_sul_crop.csv").pivot_table(index="acquisition",
                   columns="geocodig_m",
                   values="mean").interpolate()*0.02 - 273.15
modlstd = pd.read_csv(datafolder+"drought_consultas_br_mod_lstd_big_sul_crop.csv").pivot_table(index="acquisition",
                   columns="geocodig_m",
                   values="mean").interpolate()*0.02 - 273.15
mydlstn = pd.read_csv(datafolder+"drought_consultas_br_myd_lstn_big_sul_crop.csv").pivot_table(index="acquisition",
                   columns="geocodig_m",
                   values="mean").interpolate()*0.02 - 273.15
modlstn = pd.read_csv(datafolder+"drought_consultas_br_mod_lstn_big_sul_crop.csv").pivot_table(index="acquisition",
                   columns="geocodig_m",
                   values="mean").interpolate()*0.02 - 273.15


aux = pd.read_csv(datafolder+"drought_consultas_br_aux_big_sul_crop.csv")
# Out:
# CPU times: user 10.7 s, sys: 1.86 s, total: 12.5 s
# Wall time: 13 s

# %%
aux.head()
# Out:
#    geocodig_m sigla      nome_munic microrregi           nome_micro      area
# 0   3500105.0    SP      Adamantina      35035           Adamantina  0.035899
# 1   3500204.0    SP          Adolfo      35004  So Jos do Rio Preto  0.018324
# 2   3500303.0    SP            Agua      35029         Pirassununga  0.041458
# 3   3500402.0    SP   guas da Prata      35030  So Joo da Boa Vista  0.012509
# 4   3500501.0    SP  guas de Lindia      35033               Amparo  0.005265

# %%
# %%time
#ZSCORES
zgpp = xu.zscore(gpp,index=True)
zlstd = xu.zscore(modlstd,index=True)
zlstn = xu.zscore(modlstn,index=True)
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas/core/groupby.py:814: RuntimeWarning: Mean of empty slice
#   f = lambda x: func(x, *args, **kwargs)
# /usr/local/lib/python3.5/dist-packages/numpy/lib/nanfunctions.py:1423: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# CPU times: user 35.2 s, sys: 0 ns, total: 35.2 s
# Wall time: 35.3 s

# %% [markdown]
# ### exploratory boxplots
# * PR = 41020, 41030, 41034, 41043, 41073, 41037, 41094, 41032, 41144
# * SC = 42025, 42036
# * RS = 43011, 43050, 43002, 43053, 43100, 43069, 43059, 43056, 43032, 43046

# %%
#Temperatures
plt.figure(figsize=(8,5))
plt.title('gpp'.upper())
sn.boxplot(xu.piv_table(gpp,aux,'PR','sigla'),width=0.5,linewidth=.75, color='grey')
line = xu.piv_table(gpp,aux,'PR','sigla').median(axis=0)
sn.pointplot(x=line.index, y=line.values, color='black', markers='d')
plt.show()
plt.figure(figsize=(8,5))
sn.boxplot(xu.piv_table(gpp,aux,'SC','sigla'),width=0.5,linewidth=.75, color='grey')
line = xu.piv_table(gpp,aux,'SC','sigla').median(axis=0)
sn.pointplot(x=line.index, y=line.values, color='black', markers='d')
plt.show()
plt.figure(figsize=(8,5))
sn.boxplot(xu.piv_table(gpp,aux,'RS','sigla'),width=0.5,linewidth=.75, color='grey')
line = xu.piv_table(gpp,aux,'PR','sigla').median(axis=0)
sn.pointplot(x=line.index, y=line.values, color='black', markers='d')
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py:2171: UserWarning: The boxplot API has been changed. Attempting to adjust your arguments for the new API (which might not work). Please update your code. See the version 0.6 release notes for more info.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(10,6))
plt.title('modlstn'.upper())
sn.boxplot(xu.piv_table(modlstn,aux,'PR','sigla'),width=0.5,linewidth=.75, color='grey')
line = xu.piv_table(modlstn,aux,'PR','sigla').median(axis=0)
sn.pointplot(x=line.index, y=line.values, color='black', markers='d')
plt.show()
plt.figure(figsize=(10,6))
sn.boxplot(xu.piv_table(modlstn,aux,'SC','sigla'),width=0.5,linewidth=.75, color='grey')
line = xu.piv_table(modlstn,aux,'SC','sigla').median(axis=0)
sn.pointplot(x=line.index, y=line.values, color='black', markers='d')
plt.show()
plt.figure(figsize=(10,6))
sn.boxplot(xu.piv_table(modlstn,aux,'RS','sigla'),width=0.5,linewidth=.75, color='grey')
line = xu.piv_table(modlstn,aux,'PR','sigla').median(axis=0)
sn.pointplot(x=line.index, y=line.values, color='black', markers='d')
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py:2171: UserWarning: The boxplot API has been changed. Attempting to adjust your arguments for the new API (which might not work). Please update your code. See the version 0.6 release notes for more info.
#   warnings.warn(msg, UserWarning)

# %%
#RS
criterion = 'microrregi'
lista = ['43011'] #reg Cruz Alta


plt.figure(figsize=(8,5))
plt.title('gpp'.upper())
sn.boxplot(xu.piv_table(gpp,aux,lista,criterion),width=0.5,linewidth=.75, color='grey')
line = xu.piv_table(gpp,aux,lista,criterion).median(axis=0)
sn.pointplot(x=line.index, y=line.values, color='black', markers='d')
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py:2171: UserWarning: The boxplot API has been changed. Attempting to adjust your arguments for the new API (which might not work). Please update your code. See the version 0.6 release notes for more info.
#   warnings.warn(msg, UserWarning)

# %%
#PR
criterion = 'microrregi' 
lista = ['41005'] #reg Campo Mourao


plt.figure(figsize=(8,5))
plt.title('gpp'.upper())
sn.boxplot(xu.piv_table(gpp,aux,lista,criterion),width=0.5,linewidth=.75, color='grey')
line = xu.piv_table(gpp,aux,lista,criterion).median(axis=0)
sn.pointplot(x=line.index, y=line.values, color='black', markers='d')
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py:2171: UserWarning: The boxplot API has been changed. Attempting to adjust your arguments for the new API (which might not work). Please update your code. See the version 0.6 release notes for more info.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# * PR = 41020, 41030, 41034, 41043, 41073, 41037, 41094, 41032, 41144
# * SC = 42025, 42036
# * RS = 43050, 43002, 43053, 43100, 43069, 43059, 43056, 43032, 43046

# %%
#all temperatures

criterion = 'microrregi'
lista = ['41005'] #reg Campo Mourao
#lista = [43011] #reg Cruz Alta


plt.figure(figsize=(10,6))

line1 = xu.piv_table(modlstd,aux,lista,criterion).median(axis=0)
line2 = xu.piv_table(modlstn,aux,lista,criterion).median(axis=0)
line3 = xu.piv_table(mydlstd,aux,lista,criterion).median(axis=0)
line4 = xu.piv_table(mydlstn,aux,lista,criterion).median(axis=0)
plt.plot(line1.values, label='MOD LSTD')
plt.plot(line2.values, label='MOD LSTN')
plt.plot(line3.values, label='MYD LSTD')
plt.plot(line4.values, label='MYD LSTN')

plt.ylabel(r'\textbf{temperature} ($^o$Celcius)',fontsize=16)
plt.xticks(range(12),(line1.index),fontsize=16)
plt.legend()

lista = ['43011'] #reg Cruz Alta


plt.figure(figsize=(10,6))

line1 = xu.piv_table(modlstd,aux,lista,criterion).median(axis=0)
line2 = xu.piv_table(modlstn,aux,lista,criterion).median(axis=0)
line3 = xu.piv_table(mydlstd,aux,lista,criterion).median(axis=0)
line4 = xu.piv_table(mydlstn,aux,lista,criterion).median(axis=0)
plt.plot(line1.values, label='MOD LSTD')
plt.plot(line2.values, label='MOD LSTN')
plt.plot(line3.values, label='MYD LSTD')
plt.plot(line4.values, label='MYD LSTN')

plt.ylabel(r'\textbf{temperature} ($^o$Celcius)',fontsize=16)
plt.xticks(range(12),(line1.index),fontsize=16)
plt.legend()

# %% [markdown]
# Temperaturas nas regioes de Campo Mourao e Cruz Alta. LSTN for Terra e Aqua sao iguais, vale manter o Terra por causa da serie maior. De dia, as to Aqua sao maiores que do Terra por causa do horário.

# %%
criterion = 'microrregi'
dates = ['2012-08-05','2014-02']
group = ['43011'] #Cruz Alta
group = ['41005'] #reg Campo Mourao

fmt = "%Y-%m-%d"
r = '20D'
plt.figure(figsize=(15,6))
plt.plot(xu.weightaux(zgpp,aux,criterion,group).resample(r).mean().loc[dates[0]:dates[1]], label='GPP')
plt.plot(xu.weightaux(esi,aux,criterion,group).resample(r).mean().loc[dates[0]:dates[1]], label='ESI')


#plt.plot(xu.reindexing(pd.DataFrame(xu.weightaux(zgpp,aux,criterion,group)),fmt=fmt).resample(r).mean().loc[dates[0]:dates[1]], label='GPP')
#plt.plot(xu.reindexing(pd.DataFrame(xu.weightaux(esi,aux,criterion,group)),fmt=fmt).resample(r).mean().loc[dates[0]:dates[1]], label='ESI')
#plt.plot(xu.weightaux(zlstd,aux,criterion,group).resample('8D').mean().loc[dates[0]:dates[1]], label='T_day')

plt.axhline(y=0)
plt.legend()

# %%
df = xu.reindexing(pd.DataFrame(xu.weightaux(zgpp,aux,criterion,group)),fmt="%Y-%m-%d")
df.head()
# Out:
#                    0
# 2001-08-13 -1.540927
# 2001-08-14 -1.468103
# 2001-08-15 -1.395278
# 2001-08-16 -1.322454
# 2001-08-17 -1.249630

# %%
plt.plot(xu.reindexing(df,fmt="%Y-%m-%d"))

# %% [markdown]
# ### VAR

# %%
from statsmodels.tsa.api import *
import statsmodels.api as sm

# %%
#Functions to build the datasets
def construir(criterion,group,dates):

    a = xu.weightaux(gpp,aux,criterion,group).loc[dates[0]:dates[1]].to_frame()
    b = xu.weightaux(esi,aux,criterion,group).loc[dates[0]:dates[1]].to_frame()
    c = xu.weightaux(modlstd,aux,criterion,group).loc[dates[0]:dates[1]].to_frame()
    d = xu.weightaux(modlstn,aux,criterion,group).loc[dates[0]:dates[1]].to_frame()
    #e = xu.weightaux(mydlstd,aux,criterion,group).loc[dates[0]:dates[1]].to_frame()
    #f = xu.weightaux(mydlstn,aux,criterion,group).loc[dates[0]:dates[1]].to_frame()
    g = xu.weightaux(zprec,aux,criterion,group).loc[dates[0]:dates[1]].to_frame()

    dfs = [a,b,c,d,g]
    final = reduce(lambda left,right: pd.merge(left,right, how='outer',
                                               right_index=True,left_index=True), dfs)
    final.columns = [['GPP','ESI','LSTD','LSTN','ZPREC']]#'MYDLSTD','MYDLSTN',
    final = final.interpolate('values',limit_direction='both')
    return final

def construirz(criterion,group,dates):

    a = xu.weightaux(zgpp,aux,criterion,group).loc[dates[0]:dates[1]].to_frame()
    b = xu.weightaux(esi,aux,criterion,group).loc[dates[0]:dates[1]].to_frame()
    c = xu.weightaux(zlstd,aux,criterion,group).loc[dates[0]:dates[1]].to_frame()
    d = xu.weightaux(zlstn,aux,criterion,group).loc[dates[0]:dates[1]].to_frame()
    #e = xu.weightaux(mydlstd,aux,criterion,group).loc[dates[0]:dates[1]].to_frame()
    #f = xu.weightaux(mydlstn,aux,criterion,group).loc[dates[0]:dates[1]].to_frame()
    g = xu.weightaux(zprec,aux,criterion,group).loc[dates[0]:dates[1]].to_frame()

    dfs = [a,b,c,d,g]
    final = reduce(lambda left,right: pd.merge(left,right, how='outer',
                                               right_index=True,left_index=True), dfs)
    final.columns = [['zGPP','ESI','zLSTD','zLSTN','ZPREC']]#'MYDLSTD','MYDLSTN',
    final = final.interpolate('values',limit_direction='both')
    return final

# %%
criterion = 'microrregi'
lista = [41005] #reg Campo Mourao 11 a 2
#lista = [43011] #reg Cruz Alta 12 a 3
#lista = [43017] #Tupanciretan
#lista = [43005] #krisiun
dates = ['2002-08-05','2016-12']

# %% [raw]
# def fenologia(var,b=12+2,a=3+1):
#     '''
#         Dirty phenology:
#             The function detects the peaks for each season based on
#         GPP or NDVI (or other ok VI). You'd better to know beforehand
#         what you're analyzing so set the n of weeks before and after
#         the peak to constrain your analysis.
#
#         var: dataframe with the data, preferred GPP or NDVI
#         parameter b, a, lb and la are given in weeks.
#         b = weeks before the peak, usually 12 for soybean
#             +2 for margin
#         a = weeks after the peak, usually 3 for soybean
#             +1 for margin
#
#         -------
#         Example:
#         xu.fenologia(xu.weightaux(gpp,aux,criterion,43011))
#     '''
#
#     peak = [];peakd = []
#     for y in np.unique(var.index.year):
#         peakd.append(np.argmax(var.loc[var.index.year==y]))
#         peak.append(np.max(var.loc[var.index.year==y]))
#
#     df2 = pd.DataFrame(data={'date':peakd,'value': peak},index=pd.DatetimeIndex(peakd))
#     df2['week'] = df2.index.weekofyear
#
#     p = df2.week.median()
#     sos = p - b
#     eos = p + a
#     if sos < 0:
#         sos = 52 + sos
#     if eos > 52:
#         eos = abs(52 - eos)
#     print(sos,p,eos)
#     return sos,p,eos

# %%
g = xu.fenologia(xu.weightaux(gpp,aux,criterion,lista))

df = construirz(criterion,lista,dates).resample('W').mean()
#from november do february
#choose os months or weekofyear de acordo com calendario agricola
df = df[(df.index.weekofyear>g[0])|(df.index.weekofyear<g[2])]
df.head(),df.tail()
# Out:
# 44.0 6.0 10.0
# (                zGPP       ESI     zLSTD     zLSTN     ZPREC
#  2002-11-10  0.990686 -0.233175 -1.181818 -0.203147  1.000000
#  2002-11-17 -0.061237 -0.227472 -1.340112  1.247704  0.550000
#  2002-11-24 -1.010874 -0.338008 -1.741356  1.874077  0.050000
#  2002-12-01 -2.120290  0.108780 -2.531076  1.070750  0.697593
#  2002-12-08 -1.862524  0.195588 -2.894336 -0.737943  1.296433,
#                  zGPP       ESI     zLSTD     zLSTN     ZPREC
#  2016-12-04 -0.728734  0.026141  0.101834 -0.210598 -0.319977
#  2016-12-11  2.596322  0.202561 -0.326231 -0.956630 -0.439107
#  2016-12-18  0.130196  0.199809 -0.549432  0.339368 -0.187882
#  2016-12-25 -0.439790  0.417846 -1.080721  0.486796 -0.065629
#  2017-01-01 -0.677996  0.621762 -1.729677  0.428218 -0.015442)

# %%
m = VAR(df)
#m.select_order(10)
ml = int(np.round((12*len(df)/100)**.25,0)+1)
r = m.fit(maxlags=ml,ic='bic')

#r.summary()

# %% [raw]
# r.forecast(df.values[-r.k_ar:], 6)
# r.plot_forecast(20)
# plt.show()

# %% [markdown]
# ### impulse response analysis
# Lutkepohl 262(274)
#
# http://www.academicjournals.org/article/article1424250399_Yusuf.pdf

# %%
l = 10
irf = r.irf(l)

# %%
irf.plot(orth=True)
plt.savefig(fout+"irf_"+str(lista[0])+".pdf")

# %%
irf.plot_cum_effects(orth=True)
plt.savefig(fout+"cumirf_"+str(lista[0])+".pdf")

# %%
sigma_u = np.asarray(r.sigma_u)
sd_u = np.sqrt(np.diag(sigma_u))
fevd = r.fevd(10, sigma_u / sd_u)
fevd.plot()

# %%
#https://groups.google.com/forum/#!msg/pystatsmodels/BqMqOIghN78/2MKYw3iM3LYJ
fe = fevd.decomp[:,-1,:]
fevd_normalized = (fe / fe.sum(1)[:,None] * 100)
matriz = np.round(fevd_normalized, 2)[:,:]
matriz
# Out:
# array([[ 68.77,   3.91,  12.45,   2.86,  12.01],
#        [  1.4 ,  66.58,  15.09,   3.42,  13.52],
#        [  1.41,   1.94,  78.2 ,   6.61,  11.84],
#        [  2.03,   0.39,   8.63,  88.77,   0.18],
#        [  7.99,   0.6 ,  24.68,   5.42,  61.31]])

# %% [markdown]
# ### VARMAX

# %%
cui = VARMAX(df.iloc[:, 0:4],exog=df.iloc[:, -1], order=(1,0),trend='nc',)

ml = int(np.round((12*len(df)/100)**.25,0)+1)
cf = cui.fit()

cf.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    Statespace Model Results
# =============================================================================================
# Dep. Variable:     ['zGPP', 'ESI', 'zLSTD', 'zLSTN']   No. Observations:                  249
# Model:                                       VARX(1)   Log Likelihood                -883.879
# Date:                               Fri, 25 Aug 2017   AIC                           1827.757
# Time:                                       16:02:12   BIC                           1933.281
# Sample:                                   11-10-2002   HQIC                          1870.232
#                                         - 01-01-2017
# Covariance Type:                                 opg
# ==================================================================================================
# Ljung-Box (Q):          30.24, 80.80, 47.12, 32.65   Jarque-Bera (JB):   22.13, 450.76, 0.97, 4.24
# Prob(Q):                    0.87, 0.00, 0.20, 0.79   Prob(JB):              0.00, 0.00, 0.62, 0.12
# Heteroskedasticity (H):     0.92, 0.38, 0.86, 0.65   Skew:                0.16, 0.72, -0.15, -0.09
# Prob(H) (two-sided):        0.70, 0.00, 0.50, 0.05   Kurtosis:              4.42, 9.43, 3.08, 3.61
#                           Results for equation zGPP
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# L1.zGPP        0.4470      0.064      7.010      0.000       0.322       0.572
# L1.ESI         0.0637      0.070      0.912      0.362      -0.073       0.200
# L1.zLSTD      -0.1560      0.079     -1.973      0.049      -0.311      -0.001
# L1.zLSTN      -0.0016      0.053     -0.030      0.976      -0.106       0.103
# beta.ZPREC     0.1286      0.094      1.363      0.173      -0.056       0.314
#                            Results for equation ESI
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# L1.zGPP       -0.0118      0.038     -0.310      0.757      -0.086       0.063
# L1.ESI         0.8281      0.041     20.208      0.000       0.748       0.908
# L1.zLSTD      -0.0911      0.044     -2.053      0.040      -0.178      -0.004
# L1.zLSTN       0.0397      0.040      0.988      0.323      -0.039       0.118
# beta.ZPREC     0.0824      0.041      2.009      0.045       0.002       0.163
#                           Results for equation zLSTD
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# L1.zGPP        0.0840      0.057      1.482      0.138      -0.027       0.195
# L1.ESI        -0.0736      0.057     -1.288      0.198      -0.186       0.038
# L1.zLSTD       0.6840      0.067     10.283      0.000       0.554       0.814
# L1.zLSTN      -0.1514      0.056     -2.718      0.007      -0.261      -0.042
# beta.ZPREC    -0.0303      0.068     -0.449      0.653      -0.163       0.102
#                           Results for equation zLSTN
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# L1.zGPP        0.0251      0.072      0.347      0.728      -0.117       0.167
# L1.ESI         0.0403      0.070      0.577      0.564      -0.097       0.177
# L1.zLSTD       0.0014      0.078      0.018      0.986      -0.151       0.154
# L1.zLSTN       0.4691      0.064      7.384      0.000       0.345       0.594
# beta.ZPREC    -0.0239      0.081     -0.294      0.769      -0.183       0.136
#                                 Error covariance matrix
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# sqrt.var.zGPP            0.6936      0.028     25.017      0.000       0.639       0.748
# sqrt.cov.zGPP.ESI        0.0620      0.028      2.200      0.028       0.007       0.117
# sqrt.var.ESI             0.3798      0.016     23.768      0.000       0.348       0.411
# sqrt.cov.zGPP.zLSTD     -0.0643      0.039     -1.630      0.103      -0.142       0.013
# sqrt.cov.ESI.zLSTD       0.0037      0.045      0.083      0.934      -0.084       0.091
# sqrt.var.zLSTD           0.6393      0.032     20.144      0.000       0.577       0.701
# sqrt.cov.zGPP.zLSTN     -0.1216      0.050     -2.420      0.016      -0.220      -0.023
# sqrt.cov.ESI.zLSTN       0.0290      0.053      0.543      0.587      -0.076       0.134
# sqrt.cov.zLSTD.zLSTN     0.2206      0.049      4.463      0.000       0.124       0.317
# sqrt.var.zLSTN           0.7050      0.033     21.668      0.000       0.641       0.769
# ========================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
cf.plot_diagnostics(variable=0,figsize=(10,10))#variable=0 is GPP (the first)
plt.savefig(fout+"varmax_diag_"+str(lista[0])+".pdf")

# %%
cf.impulse_responses(steps=10).iloc[:, 1:4].plot(title='GPP')
plt.savefig(fout+"varmax_irf_on_gpp_"+str(lista[0])+".pdf")

# %% [markdown]
# Precipitation not included here, as I used it as an exogenous variable.
