# %%
import pandas as pd
import numpy as np
import pylab as plt
from scipy import stats
from functools import reduce
import os, sys
#for mac
sys.path.append('/Users/denismariano/pcloud/mypy')
import xuleta as xu


month_names = pd.date_range(start='2016-01-01', periods=12, freq='MS').strftime('%b')


#for SQL
from sqlalchemy import create_engine
engine = create_engine('postgresql://denis:sinedoom48@localhost:5432/drought')
fout = '/Users/denismariano/pcloud/PB_carlos/Document/elsevier_sample/images/'#mac
fout = '/home/denis/pcloud/0NEWPROJ/plots/'

# %%
def piv_table(var,lista,resample='M'):
    region_var = weightaverage(var,lista)
    region_var = pd.DataFrame(region_var)
    region_var.columns = ['values']
    region_var = region_var.resample('M').mean()

    region_var['year'] = region_var.index.year
    region_var['month'] = region_var.index.month
    region_var_piv = region_var.pivot(index='year', columns='month', values='values')
    region_var_piv.columns = month_names
    return region_var_piv

def weightaverage(var,region_number,area):
    '''
        var (pandas DataFrame): dataset containing the variable, either extracted from SQL or CSV, or the z-score of it
        region_number (int): group number (from grouped, in this case)
        area (float): threshold for minimum area to be considered for a municipality to be included in the weight average
    '''

    #area threshold -> I HAVE TO VERIFY WHAT THESE AREAS MEAN IN THE MAP

    l = list(aux[(aux['microrregi'].isin(grouped[region_number])) & (aux['area']> area)].geocodig_m)
    a = aux[aux['geocodig_m'].isin(l)]
    a['w'] = a.area/sum(a.area)
    a = a[['geocodig_m','w']]
    a.index = a.geocodig_m
    a.drop("geocodig_m",inplace=True,axis=1)
    a = a.T
    var_aw = pd.DataFrame(var[a.columns].values*a.values, columns=a.columns,index=var[a.columns].index)
    var_final = var_aw.sum(axis=1,skipna=True)
    var_final.index = pd.DatetimeIndex(var_final.index)
    print('A total of %d municipalities were considered' %var_aw.shape[1])
    return(var_final)

# %%
# %%time
# MODIS ET
#FILTERED NDVI
try:
    ndvi = pd.read_sql("SELECT * FROM consultas_br.ndvi",engine).pivot_table(index="acquisition",
                   columns="geocodig_m",
                   values="mean").interpolate()/10000
except:
    ndvi = pd.read_csv("../SQL/drought_consultas_br_ndvi.csv").pivot_table(index="acquisition",
                   columns="geocodig_m",
                   values="mean").interpolate()/10000
#ZNDVI
zndvi = xu.zscore(ndvi, index=True)

#CROP AREAS  
# it doesn't work when I read from SQL
aux = pd.read_csv("../SQL/drought_consultas_br_aux_big_sul_crop.csv")

# LIST OF MUNICIPALITIES, MESO, MICROregions
sulmuni = pd.read_csv("../SQL/sul_muni.csv")
sulmuni.drop(["sigla","nome_muni","muni"],axis=1,inplace=True)
# Out:
# /Users/denismariano/pcloud/mypy/xuleta.py:695: FutureWarning: pd.groupby() is deprecated and will be removed Please use the Series.groupby() or DataFrame.groupby() methods
#   mean=pd.groupby(df,by=[df.index.dayofyear]).aggregate(np.nanmean)
# /Users/denismariano/pcloud/mypy/xuleta.py:696: FutureWarning: pd.groupby() is deprecated and will be removed Please use the Series.groupby() or DataFrame.groupby() methods
#   std= pd.groupby(df,by=[df.index.dayofyear]).aggregate(np.nanstd)
# CPU times: user 11.2 s, sys: 271 ms, total: 11.5 s
# Wall time: 11.6 s

# %%
# REMEMBER TO COMPARE THIS GROUPS WITH THE HCC GROUPS
regions = [41004, 41005, 41007, 41008, 41009, 41010, 41011, 41012, 41013, 41014, 41015, 41019, 
           41020, 41021, 41022, 41023, 41024, 41027, 41028, 41029, 41030, 42003, 43005,  43008, 
           43009, 43010, 43011, 43012, 43017]

grouped = [[41019,41020, 41021], #ce-PR
           [41007, 41008, 41009, 41010, 41011, 41012, 41013, 41014, 41015], #cn-PR
           [41004, 41005,41022, 41023, 41024], #cw-PR
           [41027, 41028, 41029, 41030, 42003], #sw-PR
           [43005,  43008,43009, 43010, 43011, 43012, 43017]] #nw-RS

# %%
area = 13000
zndvi0=weightaverage(zndvi,region_number=0,area=area)
zndvi1=weightaverage(zndvi,region_number=1,area=area)
zndvi2=weightaverage(zndvi,region_number=2,area=area)
zndvi3=weightaverage(zndvi,region_number=3,area=area)
zndvi4=weightaverage(zndvi,region_number=4,area=area)

ndvi0=weightaverage(ndvi,region_number=0,area=area)
ndvi1=weightaverage(ndvi,region_number=1,area=area)
ndvi2=weightaverage(ndvi,region_number=2,area=area)
ndvi3=weightaverage(ndvi,region_number=3,area=area)
ndvi4=weightaverage(ndvi,region_number=4,area=area)
# Out:
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# A total of 85 municipalities were considered
# A total of 75 municipalities were considered
# A total of 124 municipalities were considered
# A total of 99 municipalities were considered
# A total of 104 municipalities were considered
# A total of 85 municipalities were considered
# A total of 75 municipalities were considered
# A total of 124 municipalities were considered
# A total of 99 municipalities were considered
# A total of 104 municipalities were considered

# %% [markdown]
# ### Phenology and NDVI metrics

# %%
#NEW APPROACH, merge p and r
def phenosimple(r,w):
    '''
        g is the input dataframe
        p is the output dataframe
        r is the region [r1...r5]
        w is the window (int)
        Return: [0] -> r (the dataframe)
                [1] -> phenos (summary dataframe)
    '''
    r = pd.DataFrame(r)
    r.index.names = ['acquisition']
    r.columns = ['NDVI']
    r = r.rolling(w).mean()
    years = [x for x in np.arange(r.index.year.min(),r.index.year.max()+1)]
    p = pd.DataFrame(index=years)
    p['dateSOS'] = None
    p['dateEOS'] = None
    p['SOS'] = None
    p['EOS'] = None
    #p['LOS'] = None

    #PHENOLOGY calculator
    for i in years[:-1]:
        rtemp = r.loc[str(i)+"-10":str(i+1)+"-02"]
        p['dateSOS'][i] = rtemp['NDVI'].argmin()
        p['SOS'][i] = rtemp['NDVI'].min()
        p['dateEOS'][i] = rtemp['NDVI'].argmax()
        p['EOS'][i] = rtemp['NDVI'].max()
        #p['LOS'][i] = (rtemp['NDVI'].argmax() - rtemp['NDVI'].argmin()).days
    p = p[:-1] #remove the None row (last)
    
    pSOS = p[['dateSOS','SOS']]
    pSOS.index = pSOS.dateSOS
    pSOS.drop('dateSOS',inplace=True,axis=1)
    pEOS = p[['dateEOS','EOS']]
    pEOS.index = pEOS.dateEOS
    pEOS.drop('dateEOS',inplace=True,axis=1)
    r = pd.DataFrame(r)
    r.columns = ['NDVI']
    r = pd.merge(r, pSOS, left_index=True, right_index=True, how='outer')
    r = pd.merge(r, pEOS, left_index=True, right_index=True, how='outer')
    r['DOY'] = [x.dayofyear for x in r.index]
    r['year'] = [x.year for x in r.index]
    
    # SUMMARY DATAFRAME WITH LOS
    sos = r[['SOS','year','DOY']][r['SOS'].notnull()]
    pos = r[['EOS','year','DOY']][r['EOS'].notnull()]

    phenos = pd.merge(sos,pos,how='outer',left_index=True, right_index=True)
    phenos['LOS'] = None
    for i in range(len(phenos[1:])):
        phenos['LOS'][i+1] = (phenos.index[i+1]-phenos.index[i]).days
    phenos['LOS'][phenos['LOS'] > 190] = None 

    return(r,phenos)

## transfering Yp to another DataFrame
def Yp(summa):
    #yields dataframe has to be created first like:
    # yields = pd.DataFrame(index=range(2002,2018))
    #np.log10(np.asarray(summa[1::2]['LOS'].values,dtype=np.float32))
    
    Yp = (summa[1::2]['EOS'].values-summa[::2]['SOS'].values)*summa[1::2]['LOS'].values
    summa['Yp'] = None
    for i,Y in zip(np.arange(1,len(summa),2),Yp):
        summa['Yp'].iloc[i] = Y

    yields=summa['Yp'][summa.Yp.notnull()].values
    return(yields)

# %%
# for convenience, if I want to make some plotting loops
groups = [ndvi0,ndvi1,ndvi2,ndvi3,ndvi4]
groupnames = ['ce-PR','cn-PR','cw-PR','sw-PR','nw-RS']

# %%
# GROUPING IN A SIMPLE DATAFRAME
yields = pd.DataFrame(index=range(2002,2018))

for i in range(5):
    summa = phenosimple(groups[i],8)[1]
    yields[groupnames[i]] = Yp(summa)
yields = yields[:-1]
# Out:
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
yields
# Out:
#         ce-PR    cn-PR    cw-PR    sw-PR    nw-RS
# 2002  26.6335  46.9528  35.9708  23.0173  21.7588
# 2003  19.6232  38.5731  36.5199  20.7157  23.7294
# 2004  19.9617  47.0694  41.0872  16.8923  22.2056
# 2005  20.1999  36.1663  33.1998  16.8852  17.2137
# 2006  23.6933  32.3109  27.4218  18.2491  19.0901
# 2007  20.0279  38.6308  29.1457  16.3209  25.1429
# 2008  24.8816  46.6646   43.928  18.3277  21.7226
# 2009   17.697  37.0319  28.0262   19.605  19.8718
# 2010    15.54  26.9706  22.4308  6.04978  19.2331
# 2011  22.1485  39.6797   31.614  13.9572  24.6745
# 2012  26.5326  40.2798  29.6524  14.4023  13.3861
# 2013  19.8468  44.6282  35.2055  17.4137  28.3869
# 2014  18.1936  37.2344  36.1714  16.0309  24.0359
# 2015  21.3516  41.1062  29.5281  12.1964  26.0877
# 2016  16.0033  28.1136   23.338  9.75472  31.5696

# %%
yieldslog10 = pd.DataFrame(index=range(2002,2017))
for i in yields.columns:
    yieldslog10[i] = np.log10(np.asarray(yields[i].values,dtype=np.float32))
yieldslog10
# Out:
#          ce-PR     cn-PR     cw-PR     sw-PR     nw-RS
# 2002  1.425428  1.671662  1.555950  1.362055  1.337636
# 2003  1.292770  1.586284  1.562529  1.316300  1.375286
# 2004  1.300198  1.672739  1.613707  1.227690  1.346462
# 2005  1.305349  1.558304  1.521136  1.227505  1.235874
# 2006  1.374626  1.509349  1.438095  1.261243  1.280808
# 2007  1.301635  1.586933  1.464574  1.212744  1.400416
# 2008  1.395878  1.668988  1.642741  1.263108  1.336911
# 2009  1.247899  1.568576  1.447564  1.292366  1.298237
# 2010  1.191451  1.430891  1.350846  0.781740  1.284049
# 2011  1.345344  1.598568  1.499879  1.144797  1.392248
# 2012  1.423780  1.605088  1.472059  1.158433  1.126655
# 2013  1.297690  1.649609  1.546610  1.240891  1.453118
# 2014  1.259917  1.570944  1.558366  1.204959  1.380861
# 2015  1.329430  1.613907  1.470235  1.086232  1.416436
# 2016  1.204209  1.448917  1.368063  0.989215  1.499269

# %% [markdown]
# #### some conclusions
# * Apparently, I can't figure a metric to correlate pheno-NDVI with yield
# * visually, by looking at the yield maps, the correlations don't seem to be strong

# %%
yso = pd.read_csv("../tabular/rendsoja.csv", index_col='cod').loc[:,'2002':'2016']
ys = yso.T.copy()
ys
# Out:
# cod   4100103  4100202  4100301  4100400  4100459  4100509  4100608  4100707  \
# 2002   2100.0      NaN      NaN      NaN   3100.0   2600.0   2480.0   3100.0
# 2003   1680.0      NaN      NaN      NaN   3175.0   2500.0   2480.0   3350.0
# 2004   2600.0      NaN      NaN      NaN   3100.0   1050.0   1487.0   2300.0
# 2005   1750.0      NaN      NaN      NaN   2460.0   1800.0   1365.0   2300.0
# 2006   2100.0      NaN      NaN      NaN   2950.0   1255.0   1734.0   2700.0
# 2007   2600.0      NaN      NaN      NaN   2950.0   2355.0   2727.0   3193.0
# 2008   2600.0      NaN      NaN      NaN   2749.0   2600.0   2400.0   2701.0
# 2009   2080.0      NaN      NaN      NaN   2749.0   1300.0   1620.0   2097.0
# 2010   2590.0      NaN   2850.0      NaN   3250.0   3000.0   2899.0   3130.0
# 2011   3350.0      NaN   3350.0   3000.0   3200.0   2773.0   2899.0   3310.0
# 2012   2320.0      NaN   3153.0   2000.0   2197.0    815.0   1737.0   2000.0
# 2013   3100.0      NaN   3220.0   2268.0   3223.0   2137.0   2880.0   3000.0
# 2014   1460.0      NaN   2891.0      NaN   3471.0   1800.0   2000.0   3192.0
# 2015   2640.0      NaN   3101.0      NaN   3099.0   2455.0   1800.0   3488.0
# 2016   2760.0      NaN   3200.0   3000.0   2871.0   2780.0   2221.0   2589.0
#
# cod   4100806  4100905   ...     4323309  4323358  4323408  4323457  4323507  \
# 2002   2580.0   2500.0   ...      3000.0   1500.0   2400.0   1500.0   1296.0
# 2003   3300.0   2850.0   ...      3000.0   3300.0   3000.0   2100.0   2220.0
# 2004   1920.0   1735.0   ...      1200.0   2040.0   2100.0    840.0   1100.0
# 2005   1860.0   2330.0   ...         NaN    540.0    300.0    420.0    600.0
# 2006   2580.0   2000.0   ...      2400.0   3000.0   2400.0    630.0   1582.0
# 2007   2880.0      NaN   ...      2400.0   3300.0   3300.0   1920.0   1859.0
# 2008   2880.0      NaN   ...      2400.0   2500.0   2100.0   1440.0    748.0
# 2009   2279.0   2228.0   ...      2500.0   2520.0   2550.0   1500.0   1292.0
# 2010   3120.0   3199.0   ...      2500.0   3300.0   3300.0   2400.0   2400.0
# 2011   3415.0   3100.0   ...      3700.0   3600.0   3300.0   2400.0   3300.0
# 2012   2724.0   1850.0   ...      2100.0   2700.0   2100.0   1260.0    735.0
# 2013   3260.0   2800.0   ...      3600.0   2400.0   3300.0   2500.0   2100.0
# 2014   1500.0   2200.0   ...      3000.0   3000.0   3600.0   3000.0   1755.0
# 2015   3103.0   3372.0   ...      3500.0   4200.0   3900.0   3200.0   2400.0
# 2016   2450.0   2760.0   ...      3600.0   3600.0   3600.0   2580.0   2700.0
#
# cod   4323606  4323705  4323754  4323770  4323804
# 2002   2400.0   1307.0    750.0      NaN      NaN
# 2003   3000.0   2700.0   2100.0   1800.0      NaN
# 2004   1800.0   1440.0    780.0    900.0      NaN
# 2005    600.0    600.0    360.0      NaN      NaN
# 2006   2210.0   1080.0   1140.0   1800.0      NaN
# 2007   2210.0   2520.0   2200.0   1800.0      NaN
# 2008   2700.0   1800.0   1500.0   2400.0      NaN
# 2009   2700.0   1800.0   1500.0   2400.0      NaN
# 2010   3500.0   2400.0   2520.0   2400.0      NaN
# 2011   3500.0   3000.0   2700.0   2680.0      NaN
# 2012   1100.0   1320.0    240.0   1640.0      NaN
# 2013   3300.0   2400.0   2280.0   2680.0      NaN
# 2014   3300.0   2700.0   2100.0   3000.0      NaN
# 2015   3600.0   2700.0   2700.0   2550.0      NaN
# 2016   3900.0   3000.0   2702.0   2550.0      NaN
#
# [15 rows x 1191 columns]

# %%
def weightY(var,region_number,area):
    '''
        var (pandas DataFrame): dataset containing the variable, either extracted from SQL or CSV, or the z-score of it
        region_number (int): group number (from grouped, in this case)
        area (float): threshold for minimum area to be considered for a municipality to be included in the weight average
    '''

    #area threshold -> I HAVE TO VERIFY WHAT THESE AREAS MEAN IN THE MAP

    l = list(aux[(aux['microrregi'].isin(grouped[region_number])) & (aux['area']> area)].geocodig_m)
    a = aux[aux['geocodig_m'].isin(l)]
    a['w'] = a.area/sum(a.area)
    a = a[['geocodig_m','w']]
    a.index = a.geocodig_m
    a.drop("geocodig_m",inplace=True,axis=1)
    a = a.T
    var_aw = pd.DataFrame(var[a.columns].values*a.values, columns=a.columns,index=var[a.columns].index)
    var_final = var_aw.sum(axis=1,skipna=True)
    #var_final.index = pd.DatetimeIndex(var_final.index)
    #print('A total of %d municipalities were considered' %var_aw.shape[1])
    return(var_final.values)

# %%
#area = 13000
ibge = pd.DataFrame(index=range(2002,2017))
for i in range(5):
    ibge[groupnames[i]] = weightY(ys,i,area = 13000)
ibge
# Out:
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#             ce-PR        cn-PR        cw-PR        sw-PR        nw-RS
# 2002  3113.463054  2800.227376  3098.237325  2595.306549  1926.172174
# 2003  3302.101504  2959.121318  3137.548829  3033.030276  2979.103124
# 2004  3099.461478  2618.440849  2639.764588  2559.213879  1698.058385
# 2005  2559.096446  2199.320937  2589.116748  2012.637394   675.013752
# 2006  2723.524168  2334.650862  2423.191315  2660.526434  2293.614237
# 2007  3270.840440  2865.902500  3120.881037  2918.664532  2722.622565
# 2008  3079.428954  2911.106276  3172.577131  2794.722506  2267.119158
# 2009  2712.015465  2281.611355  2184.287805  2643.695733  2319.652775
# 2010  3164.422475  3090.676563  3334.691720  3169.607576  2752.852105
# 2011  3496.572241  3430.625381  3388.166098  3434.854755  3105.548538
# 2012  3416.501450  2654.808354  2189.247725  2531.151955  1523.350054
# 2013  3686.443053  3326.931276  3475.872423  3256.025890  2912.156733
# 2014  3202.209889  2521.112844  3419.437946  3161.165694  2773.874823
# 2015  3717.462647  3263.792544  3467.904182  3215.433766  3320.247576
# 2016  3396.783264  2664.071703  3346.973132  3336.089335  3377.035362

# %%
ibge = ibge.astype('float32')
yields = yields.astype('float32')
yieldslog10 = yieldslog10.astype('float32')

# %%
import seaborn as sn

# %%
for i in groupnames:
    sn.regplot(x=yields[i],y=ibge[i])
    plt.show()

# %%
#LOG10 on LOS
for i in groupnames:
    sn.regplot(x=yieldslog10[i],y=ibge[i])
    plt.show()

# %%
# (POS-SOS)*LOS
ibge.corrwith(yields,axis=0)
# Out:
# ce-PR    0.008258
# cn-PR    0.234101
# cw-PR    0.063597
# sw-PR   -0.465655
# nw-RS    0.764705
# dtype: float64

# %%
#LOG10 on LOS
ibge.corrwith(yieldslog10,axis=0)
# Out:
# ce-PR    0.010145
# cn-PR    0.213531
# cw-PR    0.042619
# sw-PR   -0.448740
# nw-RS    0.761311
# dtype: float64
