# %% [markdown]
# ### Database works.
# In this **notebook** we have a lot of good stuff:

# %%
# %load_ext sql
import os, getpass, time, xuleta

user = input("Username: ")
password = getpass.getpass('Enter your password: ')
database = input("Database: ")
connection_string = "postgresql://%s:%s@localhost/%s" %(user,password,database)
# %sql $connection_string
# Out:
# Username: denis
# Enter your password: ········
# Database: drought
# 'Connected: denis@drought'

# %% [markdown]
# ### INPUT PARAMETERS
# Make sure the **table** matches the list provide in the NODATA DICTIONARY block

# %%
schema = "GLEAM"
table = "swdi_surface"
imfolder = "/home/denis/Downloads/swdi_surface/"

t0 = time.time()
if imfolder[-1] != "/":
    imfolder = imfolder + "/"

nodatas = {'pet':0,'ple':0,'le':0,'et':0,'gpp':-32767,'gpp_f2':1,'albedo':32767,
          'psn':32767,'ndvi':1,'lstd':65535,'lstn':65535,'lst_day':0,'lst_night':0,
          'vpd':-32768,'lai':'nan','fpar':'nan','zscore_dec':-32768,'anom_dec':-32768,'t04':-9999,'t12':-9999,
          'prec':-9999,'landcover':0,'ndvi_f2':-30000,'SM_root_abs':'nan','SM_root_anom':'nan',
           'SM_surf_abs':'nan','SM_surf_anom':'nan','swdi_root':'nan','swdi_surface':'nan'}
nodata = str(nodatas[table])
print("nodata value for %s is set to %s" %(table.upper(),nodata))
# Out:
# nodata value for SWDI_SURFACE is set to nan

# %%
xuleta.renamedate(imfolder,oldf='%Y_%j',newf='%Y-%m-%d')
# Out:
# Done!

# %% [markdown]
# ### Creating Schema and table
#
# It might not be necessary to create a schema.

# %%
SQL = ("CREATE SCHEMA %s;" %(schema))
# %sql $SQL
# Out:
# (psycopg2.ProgrammingError) schema "gleam" already exists
#  [SQL: 'CREATE SCHEMA GLEAM;']

# %%
#CREATING TABLE
SQL = ("""
CREATE TABLE %s.%s(
rid serial NOT NULL,
rast RASTER,
filename text,
acquisition date,
CONSTRAINT %s_%s_pkey
PRIMARY KEY (rid));
CREATE INDEX %s_%s_wkb_rast_idx
ON %s.%s
USING GIST (ST_ConvexHull(rast)); """ 
       %(schema,table,schema,table,schema,table,schema,table))
# %sql $SQL
# Out:
# Done.
# Done.
# []

# %%
# %%time
comment = table.upper() + " data for " + schema + "."
SQL = ("""
COMMENT ON TABLE %s.%s 
IS '%s'
"""
    %(schema,table,comment))
# %sql $SQL
# Out:
# Done.
# CPU times: user 1.71 ms, sys: 456 µs, total: 2.17 ms
# Wall time: 31.7 ms

# %% [markdown]
# ### Importing images to the database
#
# You can watch the verbose in the terminal to make sure that things are going ok.

# %%
importraster = "raster2pgsql -a -C -F -M -s 4326 -t 100x100 -N %s %s*.tif %s.%s | psql -p 5432 -d drought -U denis" %(nodata,imfolder,schema,table)
print(importraster)
# Out:
# raster2pgsql -a -C -F -M -s 4326 -t 100x100 -N nan /home/denis/Downloads/swdi_surface/*.tif GLEAM.swdi_surface | psql -p 5432 -d drought -U denis

# %%
# %%time
os.system(importraster)
# Out:
# CPU times: user 402 µs, sys: 4.25 ms, total: 4.66 ms
# Wall time: 2.66 s
# 0

# %% [markdown]
# #### Creating date index from filename

# %%
# %%time
SQL = ("""
UPDATE %s.%s
    SET acquisition = date(
    substring(filename FROM 1 FOR 4) || '-' ||
    substring(filename FROM 6 FOR 2) || '-' ||
    substring(filename FROM 9 FOR 2))::date;
    
CREATE INDEX %s_acquisition_idx
    ON %s.%s (acquisition);
"""
      %(schema,table,table,schema,table))
#execute query
# %sql $SQL
# Out:
# 780 rows affected.
# Done.
# CPU times: user 2.42 ms, sys: 3.69 ms, total: 6.11 ms
# Wall time: 543 ms

# %%
taime = (time.time() - t0)/60
xuleta.shemale(taime)
# Out:
# To:denismeia@icloud.com
# From: denismeia@gmail.com
# Subject:PROCESS DONE
#
# done!

# %% [markdown]
# ### Testing

# %%
point = [str(-92.891),str(42.436)]#US
point = [str(-38.8),str(-8.03)] #PB
point = [str(-52.84),str(-24.48)] #PR

dates = [('1980-10-29'),('2017-01-09')]

# %%
# POINT BASED TEST
SQL = ("""SELECT 
        rid, 
        acquisition,
        ST_Value(rast, ST_SetSRID(ST_MakePoint(%s,%s), 4326)) AS %s
    FROM %s.%s
         WHERE ST_Intersects(ST_SetSRID(ST_MakePoint(%s,%s), 4326), rast)
           AND acquisition BETWEEN '%s' AND '%s'
    ORDER BY acquisition;
"""
%(point[0],point[1],table,schema,table,point[0],point[1],dates[0],dates[1]))
print(SQL)
# %sql $SQL
# Out:
# SELECT
#         rid,
#         acquisition,
#         ST_Value(rast, ST_SetSRID(ST_MakePoint(-52.84,-24.48), 4326)) AS swdi_root
#     FROM GLEAM.swdi_root
#          WHERE ST_Intersects(ST_SetSRID(ST_MakePoint(-52.84,-24.48), 4326), rast)
#            AND acquisition BETWEEN '1980-10-29' AND '2017-01-09'
#     ORDER BY acquisition;
#
# 730 rows affected.
# [(1, datetime.date(2003, 1, 1), -2.01476311683655),
#  (2, datetime.date(2003, 1, 8), -2.10800313949585),
#  (3, datetime.date(2003, 1, 15), -2.32551860809326),
#  (4, datetime.date(2003, 1, 22), -0.0472123995423317),
#  (5, datetime.date(2003, 1, 29), -1.03352200984955),
#  (6, datetime.date(2003, 2, 5), -1.0842912197113),
#  (7, datetime.date(2003, 2, 12), -0.2883320748806),
#  (8, datetime.date(2003, 2, 19), 0.452064484357834),
#  (9, datetime.date(2003, 2, 26), -0.271842539310455),
#  (10, datetime.date(2003, 3, 5), 0.0602447204291821),
#  (11, datetime.date(2003, 3, 12), -0.195978567004204),
#  (12, datetime.date(2003, 3, 19), -0.9684237241745),
#  (13, datetime.date(2003, 3, 26), -2.41470575332642),
#  (14, datetime.date(2003, 4, 2), -3.02699303627014),
#  (15, datetime.date(2003, 4, 9), -1.96118795871735),
#  (16, datetime.date(2003, 4, 16), -1.78010761737823),
#  (17, datetime.date(2003, 4, 23), -2.1806812286377),
#  (18, datetime.date(2003, 4, 30), -2.62598848342896),
#  (19, datetime.date(2003, 5, 7), -3.19039034843445),
#  (20, datetime.date(2003, 5, 14), -4.27372026443481),
#  (21, datetime.date(2003, 5, 21), -3.76673436164856),
#  (22, datetime.date(2003, 5, 28), -3.75721836090088),
#  (23, datetime.date(2003, 6, 4), -0.932607114315033),
#  (24, datetime.date(2003, 6, 11), -1.49401807785034),
#  (25, datetime.date(2003, 6, 18), -2.23152351379395),
#  (26, datetime.date(2003, 6, 25), -2.93888735771179),
#  (27, datetime.date(2003, 7, 2), -2.81187677383423),
#  (28, datetime.date(2003, 7, 9), -1.19529962539673),
#  (29, datetime.date(2003, 7, 16), -0.677755117416382),
#  (30, datetime.date(2003, 7, 23), -1.6111034154892),
#  (31, datetime.date(2003, 7, 30), -2.57439351081848),
#  (32, datetime.date(2003, 8, 6), -2.62907934188843),
#  (33, datetime.date(2003, 8, 13), -2.83847904205322),
#  (34, datetime.date(2003, 8, 20), -3.53642678260803),
#  (35, datetime.date(2003, 8, 27), -4.30586624145508),
#  (36, datetime.date(2003, 9, 3), -4.96456527709961),
#  (37, datetime.date(2003, 9, 10), -3.69934415817261),
#  (38, datetime.date(2003, 9, 17), -4.96929788589478),
#  (39, datetime.date(2003, 9, 24), -4.30017423629761),
#  (40, datetime.date(2003, 10, 1), -5.13703060150146),
#  (41, datetime.date(2003, 10, 8), -4.54361009597778),
#  (42, datetime.date(2003, 10, 15), -5.53418445587158),
#  (43, datetime.date(2003, 10, 22), -4.43627500534058),
#  (44, datetime.date(2003, 10, 29), -4.41667747497559),
#  (45, datetime.date(2003, 11, 5), -6.15283393859863),
#  (46, datetime.date(2003, 11, 12), -6.30060863494873),
#  (47, datetime.date(2003, 11, 19), -4.60238075256348),
#  (48, datetime.date(2003, 11, 26), -3.04506826400757),
#  (49, datetime.date(2003, 12, 3), -3.54039192199707),
#  (50, datetime.date(2003, 12, 10), -1.35297548770905),
#  (51, datetime.date(2003, 12, 17), -1.21951019763947),
#  (52, datetime.date(2003, 12, 24), -2.56117272377014),
#  (53, datetime.date(2004, 1, 1), -3.73024082183838),
#  (54, datetime.date(2004, 1, 8), -3.70706534385681),
#  (55, datetime.date(2004, 1, 15), -6.06256532669067),
#  (56, datetime.date(2004, 1, 22), -7.71180725097656),
#  (57, datetime.date(2004, 1, 29), -9.76522064208984),
#  (58, datetime.date(2004, 2, 5), -10.0204305648804),
#  (59, datetime.date(2004, 2, 12), -9.78039741516113),
#  (60, datetime.date(2004, 2, 19), -10.3717155456543),
#  (61, datetime.date(2004, 2, 26), -11.7123403549194),
#  (62, datetime.date(2004, 3, 4), -12.6377458572388),
#  (63, datetime.date(2004, 3, 11), -9.6232738494873),
#  (64, datetime.date(2004, 3, 18), -9.88926887512207),
#  (65, datetime.date(2004, 3, 25), -11.3884124755859),
#  (66, datetime.date(2004, 4, 1), -11.3832588195801),
#  (67, datetime.date(2004, 4, 8), -11.996148109436),
#  (68, datetime.date(2004, 4, 15), -11.6990346908569),
#  (69, datetime.date(2004, 4, 22), -8.54254055023193),
#  (70, datetime.date(2004, 4, 29), -6.19082546234131),
#  (71, datetime.date(2004, 5, 6), -3.73690223693848),
#  (72, datetime.date(2004, 5, 13), -1.41911375522614),
#  (73, datetime.date(2004, 5, 20), -0.840716421604156),
#  (74, datetime.date(2004, 5, 27), -0.691752970218658),
#  (75, datetime.date(2004, 6, 3), -0.918100237846375),
#  (76, datetime.date(2004, 6, 10), -0.503380239009857),
#  (77, datetime.date(2004, 6, 17), -1.21840679645538),
#  (78, datetime.date(2004, 6, 24), -1.00241839885712),
#  (79, datetime.date(2004, 7, 1), -1.15331828594208),
#  (80, datetime.date(2004, 7, 8), -0.535007536411285),
#  (81, datetime.date(2004, 7, 15), 0.247265607118607),
#  (82, datetime.date(2004, 7, 22), -0.439085751771927),
#  (83, datetime.date(2004, 7, 29), -1.2004486322403),
#  (84, datetime.date(2004, 8, 5), -2.21244478225708),
#  (85, datetime.date(2004, 8, 12), -3.34630274772644),
#  (86, datetime.date(2004, 8, 19), -4.47932052612305),
#  (87, datetime.date(2004, 8, 26), -4.89768886566162),
#  (88, datetime.date(2004, 9, 2), -6.08601379394531),
#  (89, datetime.date(2004, 9, 9), -6.0531005859375),
#  (90, datetime.date(2004, 9, 16), -5.63461256027222),
#  (91, datetime.date(2004, 9, 23), -6.83249950408936),
#  (92, datetime.date(2004, 9, 30), -7.26149225234985),
#  (93, datetime.date(2004, 10, 7), -7.08477210998535),
#  (94, datetime.date(2004, 10, 14), -3.14756155014038),
#  (95, datetime.date(2004, 10, 21), -1.59084594249725),
#  (96, datetime.date(2004, 10, 28), -1.34449195861816),
#  (97, datetime.date(2004, 11, 4), -0.37186598777771),
#  (98, datetime.date(2004, 11, 11), -0.0542247071862221),
#  (99, datetime.date(2004, 11, 18), -0.997761428356171),
#  (100, datetime.date(2004, 11, 25), -2.24918222427368),
#  (101, datetime.date(2004, 12, 2), -3.68020701408386),
#  (102, datetime.date(2004, 12, 9), -3.39913010597229),
#  (103, datetime.date(2004, 12, 16), -3.82545614242554),
#  (104, datetime.date(2004, 12, 23), -4.59193897247314),
#  (105, datetime.date(2005, 1, 1), -5.09488153457642),
#  (106, datetime.date(2005, 1, 8), -5.19925737380981),
#  (107, datetime.date(2005, 1, 15), -4.92255258560181),
#  (108, datetime.date(2005, 1, 22), -3.25659203529358),
#  (109, datetime.date(2005, 1, 29), -3.58260726928711),
#  (110, datetime.date(2005, 2, 5), -5.77577209472656),
#  (111, datetime.date(2005, 2, 12), -8.07449436187744),
#  (112, datetime.date(2005, 2, 19), -9.88003826141357),
#  (113, datetime.date(2005, 2, 26), -10.5496759414673),
#  (114, datetime.date(2005, 3, 5), -12.0205974578857),
#  (115, datetime.date(2005, 3, 12), -9.4444055557251),
#  (116, datetime.date(2005, 3, 19), -10.0327768325806),
#  (117, datetime.date(2005, 3, 26), -11.0077829360962),
#  (118, datetime.date(2005, 4, 2), -8.20030879974365),
#  (119, datetime.date(2005, 4, 9), -9.30073261260986),
#  (120, datetime.date(2005, 4, 16), -10.1825389862061),
#  (121, datetime.date(2005, 4, 23), -8.45808124542236),
#  (122, datetime.date(2005, 4, 30), -7.54149055480957),
#  (123, datetime.date(2005, 5, 7), -8.4397554397583),
#  (124, datetime.date(2005, 5, 14), -7.4073429107666),
#  (125, datetime.date(2005, 5, 21), -3.67565488815308),
#  (126, datetime.date(2005, 5, 28), -3.07172179222107),
#  (127, datetime.date(2005, 6, 4), -3.90812540054321),
#  (128, datetime.date(2005, 6, 11), -3.1572847366333),
#  (129, datetime.date(2005, 6, 18), -0.791432976722717),
#  (130, datetime.date(2005, 6, 25), -0.937617301940918),
#  (131, datetime.date(2005, 7, 2), -1.20043158531189),
#  (132, datetime.date(2005, 7, 9), -1.88341677188873),
#  (133, datetime.date(2005, 7, 16), -1.74059855937958),
#  (134, datetime.date(2005, 7, 23), -1.36496865749359),
#  (135, datetime.date(2005, 7, 30), -2.23783922195435),
#  (136, datetime.date(2005, 8, 6), -3.23238635063171),
#  (137, datetime.date(2005, 8, 13), -4.17309045791626),
#  (138, datetime.date(2005, 8, 20), -4.70078659057617),
#  (139, datetime.date(2005, 8, 27), -3.69415378570557),
#  (140, datetime.date(2005, 9, 3), -2.08445262908936),
#  (141, datetime.date(2005, 9, 10), -1.44888019561768),
#  (142, datetime.date(2005, 9, 17), -1.05182611942291),
#  (143, datetime.date(2005, 9, 24), -0.51669853925705),
#  (144, datetime.date(2005, 10, 1), 0.0211277771741152),
#  (145, datetime.date(2005, 10, 8), -0.021954445168376),
#  (146, datetime.date(2005, 10, 15), 0.350837826728821),
#  (147, datetime.date(2005, 10, 22), 0.437742710113525),
#  (148, datetime.date(2005, 10, 29), 0.335020542144775),
#  (149, datetime.date(2005, 11, 5), -1.25809371471405),
#  (150, datetime.date(2005, 11, 12), -2.91561698913574),
#  (151, datetime.date(2005, 11, 19), -3.29042840003967),
#  (152, datetime.date(2005, 11, 26), -3.80418539047241),
#  (153, datetime.date(2005, 12, 3), -3.73687314987183),
#  (154, datetime.date(2005, 12, 10), -5.54275560379028),
#  (155, datetime.date(2005, 12, 17), -7.65778636932373),
#  (156, datetime.date(2005, 12, 24), -8.95315456390381),
#  (157, datetime.date(2006, 1, 1), -8.39363574981689),
#  (158, datetime.date(2006, 1, 8), -10.0921173095703),
#  (159, datetime.date(2006, 1, 15), -11.2555418014526),
#  (160, datetime.date(2006, 1, 22), -9.01826000213623),
#  (161, datetime.date(2006, 1, 29), -8.98657608032227),
#  (162, datetime.date(2006, 2, 5), -10.5324020385742),
#  (163, datetime.date(2006, 2, 12), -10.0794124603271),
#  (164, datetime.date(2006, 2, 19), -6.80172681808472),
#  (165, datetime.date(2006, 2, 26), -5.56905841827393),
#  (166, datetime.date(2006, 3, 5), -6.20118713378906),
#  (167, datetime.date(2006, 3, 12), -8.08910846710205),
#  (168, datetime.date(2006, 3, 19), -8.10039043426514),
#  (169, datetime.date(2006, 3, 26), -8.03143405914307),
#  (170, datetime.date(2006, 4, 2), -9.41858005523682),
#  (171, datetime.date(2006, 4, 9), -9.46801662445068),
#  (172, datetime.date(2006, 4, 16), -7.43527317047119),
#  (173, datetime.date(2006, 4, 23), -8.35256004333496),
#  (174, datetime.date(2006, 4, 30), -9.5258321762085),
#  (175, datetime.date(2006, 5, 7), -10.4248600006104),
#  (176, datetime.date(2006, 5, 14), -10.9568481445312),
#  (177, datetime.date(2006, 5, 21), -10.9628028869629),
#  (178, datetime.date(2006, 5, 28), -11.6555118560791),
#  (179, datetime.date(2006, 6, 4), -11.6518802642822),
#  (180, datetime.date(2006, 6, 11), -12.176643371582),
#  (181, datetime.date(2006, 6, 18), -12.0664949417114),
#  (182, datetime.date(2006, 6, 25), -10.5699892044067),
#  (183, datetime.date(2006, 7, 2), -10.4456405639648),
#  (184, datetime.date(2006, 7, 9), -11.0009164810181),
#  (185, datetime.date(2006, 7, 16), -11.7056274414062),
#  (186, datetime.date(2006, 7, 23), -12.2078742980957),
#  (187, datetime.date(2006, 7, 30), -12.665057182312),
#  (188, datetime.date(2006, 8, 6), -13.3228845596313),
#  (189, datetime.date(2006, 8, 13), -11.1077060699463),
#  (190, datetime.date(2006, 8, 20), -9.00819778442383),
#  (191, datetime.date(2006, 8, 27), -8.97385692596436),
#  (192, datetime.date(2006, 9, 3), -8.57322311401367),
#  (193, datetime.date(2006, 9, 10), -8.19279766082764),
#  (194, datetime.date(2006, 9, 17), -6.66795969009399),
#  (195, datetime.date(2006, 9, 24), -5.15160322189331),
#  (196, datetime.date(2006, 10, 1), -3.96319103240967),
#  (197, datetime.date(2006, 10, 8), -4.51681995391846),
#  (198, datetime.date(2006, 10, 15), -5.27309465408325),
#  (199, datetime.date(2006, 10, 22), -6.89963150024414),
#  (200, datetime.date(2006, 10, 29), -7.01237154006958),
#  (201, datetime.date(2006, 11, 5), -4.65029048919678),
#  (202, datetime.date(2006, 11, 12), -6.0802264213562),
#  (203, datetime.date(2006, 11, 19), -5.2926778793335),
#  (204, datetime.date(2006, 11, 26), -4.72027683258057),
#  (205, datetime.date(2006, 12, 3), -5.2307333946228),
#  (206, datetime.date(2006, 12, 10), -5.80946683883667),
#  (207, datetime.date(2006, 12, 17), -5.21827268600464),
#  (208, datetime.date(2006, 12, 24), -2.11186122894287),
#  (209, datetime.date(2007, 1, 1), -1.87128221988678),
#  (210, datetime.date(2007, 1, 8), -1.21583473682404),
#  (211, datetime.date(2007, 1, 15), -1.24775910377502),
#  (212, datetime.date(2007, 1, 22), -1.80318081378937),
#  (213, datetime.date(2007, 1, 29), -3.00558829307556),
#  (214, datetime.date(2007, 2, 5), -4.15821075439453),
#  (215, datetime.date(2007, 2, 12), -5.58098840713501),
#  (216, datetime.date(2007, 2, 19), -3.90497612953186),
#  (217, datetime.date(2007, 2, 26), -2.98051810264587),
#  (218, datetime.date(2007, 3, 5), -3.12923049926758),
#  (219, datetime.date(2007, 3, 12), -2.59227633476257),
#  (220, datetime.date(2007, 3, 19), -3.2921359539032),
#  (221, datetime.date(2007, 3, 26), -4.98733425140381),
#  (222, datetime.date(2007, 4, 2), -5.12572908401489),
#  (223, datetime.date(2007, 4, 9), -4.8899827003479),
#  (224, datetime.date(2007, 4, 16), -5.76241207122803),
#  (225, datetime.date(2007, 4, 23), -4.01239919662476),
#  (226, datetime.date(2007, 4, 30), -3.96279668807983),
#  (227, datetime.date(2007, 5, 7), -2.64505243301392),
#  (228, datetime.date(2007, 5, 14), -2.14021015167236),
#  (229, datetime.date(2007, 5, 21), -0.61856335401535),
#  (230, datetime.date(2007, 5, 28), -1.47586500644684),
#  (231, datetime.date(2007, 6, 4), -2.16036772727966),
#  (232, datetime.date(2007, 6, 11), -2.93457627296448),
#  (233, datetime.date(2007, 6, 18), -3.70272731781006),
#  (234, datetime.date(2007, 6, 25), -4.30570077896118),
#  (235, datetime.date(2007, 7, 2), -5.10004997253418),
#  (236, datetime.date(2007, 7, 9), -5.48771667480469),
#  (237, datetime.date(2007, 7, 16), -3.0399386882782),
#  (238, datetime.date(2007, 7, 23), -1.6109402179718),
#  (239, datetime.date(2007, 7, 30), -2.33181977272034),
#  (240, datetime.date(2007, 8, 6), -3.46870040893555),
#  (241, datetime.date(2007, 8, 13), -4.59730195999146),
#  (242, datetime.date(2007, 8, 20), -5.77909183502197),
#  (243, datetime.date(2007, 8, 27), -5.56257963180542),
#  (244, datetime.date(2007, 9, 3), -6.45345211029053),
#  (245, datetime.date(2007, 9, 10), -7.75412225723267),
#  (246, datetime.date(2007, 9, 17), -8.56046962738037),
#  (247, datetime.date(2007, 9, 24), -8.39435195922852),
#  (248, datetime.date(2007, 10, 1), -7.93688821792603),
#  (249, datetime.date(2007, 10, 8), -7.42469263076782),
#  (250, datetime.date(2007, 10, 15), -4.88095617294312),
#  (251, datetime.date(2007, 10, 22), -4.93552017211914),
#  (252, datetime.date(2007, 10, 29), -4.63226366043091),
#  (253, datetime.date(2007, 11, 5), -3.52487683296204),
#  (254, datetime.date(2007, 11, 12), -2.01342821121216),
#  (255, datetime.date(2007, 11, 19), -2.77312994003296),
#  (256, datetime.date(2007, 11, 26), -4.89812040328979),
#  (257, datetime.date(2007, 12, 3), -4.29847145080566),
#  (258, datetime.date(2007, 12, 10), -3.03646779060364),
#  (259, datetime.date(2007, 12, 17), -5.10404205322266),
#  (260, datetime.date(2007, 12, 24), -5.92294502258301),
#  (261, datetime.date(2008, 1, 1), -5.86209726333618),
#  (262, datetime.date(2008, 1, 8), -7.59176731109619),
#  (263, datetime.date(2008, 1, 15), -8.25501441955566),
#  (264, datetime.date(2008, 1, 22), -8.43276214599609),
#  (265, datetime.date(2008, 1, 29), -7.68533420562744),
#  (266, datetime.date(2008, 2, 5), -8.71049976348877),
#  (267, datetime.date(2008, 2, 12), -8.09967422485352),
#  (268, datetime.date(2008, 2, 19), -7.49934339523315),
#  (269, datetime.date(2008, 2, 26), -6.39552927017212),
#  (270, datetime.date(2008, 3, 4), -6.12028837203979),
#  (271, datetime.date(2008, 3, 11), -4.60069036483765),
#  (272, datetime.date(2008, 3, 18), -5.38619041442871),
#  (273, datetime.date(2008, 3, 25), -6.54558181762695),
#  (274, datetime.date(2008, 4, 1), -7.869300365448),
#  (275, datetime.date(2008, 4, 8), -8.6431245803833),
#  (276, datetime.date(2008, 4, 15), -6.7538857460022),
#  (277, datetime.date(2008, 4, 22), -7.23687028884888),
#  (278, datetime.date(2008, 4, 29), -4.42944288253784),
#  (279, datetime.date(2008, 5, 6), -4.46000814437866),
#  (280, datetime.date(2008, 5, 13), -5.56649160385132),
#  (281, datetime.date(2008, 5, 20), -6.51107788085938),
#  (282, datetime.date(2008, 5, 27), -5.85641956329346),
#  (283, datetime.date(2008, 6, 3), -4.32861042022705),
#  (284, datetime.date(2008, 6, 10), -3.6486189365387),
#  (285, datetime.date(2008, 6, 17), -3.34419345855713),
#  (286, datetime.date(2008, 6, 24), -2.95609784126282),
#  (287, datetime.date(2008, 7, 1), -3.2790367603302),
#  (288, datetime.date(2008, 7, 8), -4.08232259750366),
#  (289, datetime.date(2008, 7, 15), -5.08773279190063),
#  (290, datetime.date(2008, 7, 22), -3.79043126106262),
#  (291, datetime.date(2008, 7, 29), -2.88849568367004),
#  (292, datetime.date(2008, 8, 5), -1.50443065166473),
#  (293, datetime.date(2008, 8, 12), -0.636010110378265),
#  (294, datetime.date(2008, 8, 19), -1.72218000888824),
#  (295, datetime.date(2008, 8, 26), -3.11904454231262),
#  (296, datetime.date(2008, 9, 2), -3.91287732124329),
#  (297, datetime.date(2008, 9, 9), -4.11228132247925),
#  (298, datetime.date(2008, 9, 16), -4.30288028717041),
#  (299, datetime.date(2008, 9, 23), -4.70873689651489),
#  (300, datetime.date(2008, 9, 30), -3.31148242950439),
#  (301, datetime.date(2008, 10, 7), -2.50443601608276),
#  (302, datetime.date(2008, 10, 14), -3.27976012229919),
#  (303, datetime.date(2008, 10, 21), -2.97663545608521),
#  (304, datetime.date(2008, 10, 28), -0.954781532287598),
#  (305, datetime.date(2008, 11, 4), -0.435210585594177),
#  (306, datetime.date(2008, 11, 11), -0.889230191707611),
#  (307, datetime.date(2008, 11, 18), -3.24535870552063),
#  (308, datetime.date(2008, 11, 25), -5.69689273834229),
#  (309, datetime.date(2008, 12, 2), -7.92111444473267),
#  (310, datetime.date(2008, 12, 9), -7.69298696517944),
#  (311, datetime.date(2008, 12, 16), -9.46978759765625),
#  (312, datetime.date(2008, 12, 23), -11.0252532958984),
#  (313, datetime.date(2009, 1, 1), -9.88811683654785),
#  (314, datetime.date(2009, 1, 8), -9.93552017211914),
#  (315, datetime.date(2009, 1, 15), -7.50142335891724),
#  (316, datetime.date(2009, 1, 22), -8.94799327850342),
#  (317, datetime.date(2009, 1, 29), -9.26576328277588),
#  (318, datetime.date(2009, 2, 5), -8.32053375244141),
#  (319, datetime.date(2009, 2, 12), -9.06445503234863),
#  (320, datetime.date(2009, 2, 19), -9.49488258361816),
#  (321, datetime.date(2009, 2, 26), -9.46322345733643),
#  (322, datetime.date(2009, 3, 5), -9.96752738952637),
#  (323, datetime.date(2009, 3, 12), -9.60624122619629),
#  (324, datetime.date(2009, 3, 19), -11.1252059936523),
#  (325, datetime.date(2009, 3, 26), -11.7888259887695),
#  (326, datetime.date(2009, 4, 2), -12.5802841186523),
#  (327, datetime.date(2009, 4, 9), -13.2169227600098),
#  (328, datetime.date(2009, 4, 16), -13.8463430404663),
#  (329, datetime.date(2009, 4, 23), -14.1216278076172),
#  (330, datetime.date(2009, 4, 30), -14.4733247756958),
#  (331, datetime.date(2009, 5, 7), -12.296763420105),
#  (332, datetime.date(2009, 5, 14), -9.20017051696777),
#  (333, datetime.date(2009, 5, 21), -8.24346923828125),
#  (334, datetime.date(2009, 5, 28), -5.26831102371216),
#  (335, datetime.date(2009, 6, 4), -5.32643127441406),
#  (336, datetime.date(2009, 6, 11), -4.64552116394043),
#  (337, datetime.date(2009, 6, 18), -4.44658756256104),
#  (338, datetime.date(2009, 6, 25), -2.24907493591309),
#  (339, datetime.date(2009, 7, 2), -1.32919597625732),
#  (340, datetime.date(2009, 7, 9), -0.623558938503265),
#  (341, datetime.date(2009, 7, 16), -0.832079529762268),
#  (342, datetime.date(2009, 7, 23), -0.336044520139694),
#  (343, datetime.date(2009, 7, 30), -0.395764827728271),
#  (344, datetime.date(2009, 8, 6), -1.07185959815979),
#  (345, datetime.date(2009, 8, 13), -1.22642266750336),
#  (346, datetime.date(2009, 8, 20), -0.0286111459136009),
#  (347, datetime.date(2009, 8, 27), -1.04378843307495),
#  (348, datetime.date(2009, 9, 3), -0.248296871781349),
#  (349, datetime.date(2009, 9, 10), -0.110298819839954),
#  (350, datetime.date(2009, 9, 17), -0.162200629711151),
#  (351, datetime.date(2009, 9, 24), -0.257501274347305),
#  (352, datetime.date(2009, 10, 1), -1.320756316185),
#  (353, datetime.date(2009, 10, 8), -1.27377700805664),
#  (354, datetime.date(2009, 10, 15), 0.747733533382416),
#  (355, datetime.date(2009, 10, 22), 0.7342569231987),
#  (356, datetime.date(2009, 10, 29), -1.15085089206696),
#  (357, datetime.date(2009, 11, 5), -0.494697093963623),
#  (358, datetime.date(2009, 11, 12), -0.467493027448654),
#  (359, datetime.date(2009, 11, 19), -0.652073383331299),
#  (360, datetime.date(2009, 11, 26), -1.24866282939911),
#  (361, datetime.date(2009, 12, 3), -0.463364571332932),
#  (362, datetime.date(2009, 12, 10), -0.837053179740906),
#  (363, datetime.date(2009, 12, 17), -1.8453471660614),
#  (364, datetime.date(2009, 12, 24), -1.62682330608368),
#  (365, datetime.date(2010, 1, 1), -3.35034370422363),
#  (366, datetime.date(2010, 1, 8), -1.87846994400024),
#  (367, datetime.date(2010, 1, 15), -0.0632147863507271),
#  (368, datetime.date(2010, 1, 22), -0.969519793987274),
#  (369, datetime.date(2010, 1, 29), -1.65746653079987),
#  (370, datetime.date(2010, 2, 5), -3.58729577064514),
#  (371, datetime.date(2010, 2, 12), -2.88323712348938),
#  (372, datetime.date(2010, 2, 19), -1.52433979511261),
#  (373, datetime.date(2010, 2, 26), -1.51077556610107),
#  (374, datetime.date(2010, 3, 5), -3.59115147590637),
#  (375, datetime.date(2010, 3, 12), -3.01845860481262),
#  (376, datetime.date(2010, 3, 19), -2.21927452087402),
#  (377, datetime.date(2010, 3, 26), -1.26766836643219),
#  (378, datetime.date(2010, 4, 2), -2.70630478858948),
#  (379, datetime.date(2010, 4, 9), -4.19554233551025),
#  (380, datetime.date(2010, 4, 16), -5.54886436462402),
#  (381, datetime.date(2010, 4, 23), -1.39724624156952),
#  (382, datetime.date(2010, 4, 30), -1.49648547172546),
#  (383, datetime.date(2010, 5, 7), -2.1679208278656),
#  (384, datetime.date(2010, 5, 14), -1.50502490997314),
#  (385, datetime.date(2010, 5, 21), -0.866381108760834),
#  (386, datetime.date(2010, 5, 28), -1.36867332458496),
#  (387, datetime.date(2010, 6, 4), -0.939719319343567),
#  (388, datetime.date(2010, 6, 11), -1.8060986995697),
#  (389, datetime.date(2010, 6, 18), -1.90757381916046),
#  (390, datetime.date(2010, 6, 25), -2.25551247596741),
#  (391, datetime.date(2010, 7, 2), -3.05184435844421),
#  (392, datetime.date(2010, 7, 9), -2.95646810531616),
#  (393, datetime.date(2010, 7, 16), -0.215585753321648),
#  (394, datetime.date(2010, 7, 23), -0.425577491521835),
#  (395, datetime.date(2010, 7, 30), -1.00716316699982),
#  (396, datetime.date(2010, 8, 6), -1.46991956233978),
#  (397, datetime.date(2010, 8, 13), -2.42469191551208),
#  (398, datetime.date(2010, 8, 20), -3.32378506660461),
#  (399, datetime.date(2010, 8, 27), -4.22922515869141),
#  (400, datetime.date(2010, 9, 3), -4.84654951095581),
#  (401, datetime.date(2010, 9, 10), -5.44960069656372),
#  (402, datetime.date(2010, 9, 17), -5.92687892913818),
#  (403, datetime.date(2010, 9, 24), -3.33560299873352),
#  (404, datetime.date(2010, 10, 1), -2.16133213043213),
#  (405, datetime.date(2010, 10, 8), -1.75345158576965),
#  (406, datetime.date(2010, 10, 15), -0.982538461685181),
#  (407, datetime.date(2010, 10, 22), -1.57549381256104),
#  (408, datetime.date(2010, 10, 29), -2.06444358825684),
#  (409, datetime.date(2010, 11, 5), -2.71344614028931),
#  (410, datetime.date(2010, 11, 12), -3.91517663002014),
#  (411, datetime.date(2010, 11, 19), -4.89847087860107),
#  (412, datetime.date(2010, 11, 26), -5.45628213882446),
#  (413, datetime.date(2010, 12, 3), -1.69915306568146),
#  (414, datetime.date(2010, 12, 10), -0.654530942440033),
#  (415, datetime.date(2010, 12, 17), -1.15866458415985),
#  (416, datetime.date(2010, 12, 24), -1.18787324428558),
#  (417, datetime.date(2011, 1, 1), -3.04362154006958),
#  (418, datetime.date(2011, 1, 8), -4.2196626663208),
#  (419, datetime.date(2011, 1, 15), -3.85247254371643),
#  (420, datetime.date(2011, 1, 22), -4.87386798858643),
#  (421, datetime.date(2011, 1, 29), -5.03717517852783),
#  (422, datetime.date(2011, 2, 5), -3.9709804058075),
#  (423, datetime.date(2011, 2, 12), -1.80095219612122),
#  (424, datetime.date(2011, 2, 19), -2.84724259376526),
#  (425, datetime.date(2011, 2, 26), -2.43898463249207),
#  (426, datetime.date(2011, 3, 5), -3.83000349998474),
#  (427, datetime.date(2011, 3, 12), -3.80248045921326),
#  (428, datetime.date(2011, 3, 19), -4.8977575302124),
#  (429, datetime.date(2011, 3, 26), -3.47548604011536),
#  (430, datetime.date(2011, 4, 2), -2.28093838691711),
#  (431, datetime.date(2011, 4, 9), -2.89229297637939),
#  (432, datetime.date(2011, 4, 16), -2.62283897399902),
#  (433, datetime.date(2011, 4, 23), -2.82715559005737),
#  (434, datetime.date(2011, 4, 30), -3.47203731536865),
#  (435, datetime.date(2011, 5, 7), -4.36862373352051),
#  (436, datetime.date(2011, 5, 14), -5.10148668289185),
#  (437, datetime.date(2011, 5, 21), -5.89383172988892),
#  (438, datetime.date(2011, 5, 28), -6.59194707870483),
#  (439, datetime.date(2011, 6, 4), -6.34283113479614),
#  (440, datetime.date(2011, 6, 11), -5.01238250732422),
#  (441, datetime.date(2011, 6, 18), -5.58217000961304),
#  (442, datetime.date(2011, 6, 25), -4.4519510269165),
#  (443, datetime.date(2011, 7, 2), -1.22086203098297),
#  (444, datetime.date(2011, 7, 9), -1.97044837474823),
#  (445, datetime.date(2011, 7, 16), -1.54320657253265),
#  (446, datetime.date(2011, 7, 23), -1.58012890815735),
#  (447, datetime.date(2011, 7, 30), -0.467264086008072),
#  (448, datetime.date(2011, 8, 6), -0.863765180110931),
#  (449, datetime.date(2011, 8, 13), -0.988342702388763),
#  (450, datetime.date(2011, 8, 20), 0.188502505421638),
#  (451, datetime.date(2011, 8, 27), -0.643755555152893),
#  (452, datetime.date(2011, 9, 3), -0.478750705718994),
#  (453, datetime.date(2011, 9, 10), -0.410064667463303),
#  (454, datetime.date(2011, 9, 17), -1.50074052810669),
#  (455, datetime.date(2011, 9, 24), -1.79107797145844),
#  (456, datetime.date(2011, 10, 1), -2.79559183120728),
#  (457, datetime.date(2011, 10, 8), -1.35561573505402),
#  (458, datetime.date(2011, 10, 15), -0.309880495071411),
#  (459, datetime.date(2011, 10, 22), -1.35687983036041),
#  (460, datetime.date(2011, 10, 29), -0.73053377866745),
#  (461, datetime.date(2011, 11, 5), -1.76203000545502),
#  (462, datetime.date(2011, 11, 12), -1.12147665023804),
#  (463, datetime.date(2011, 11, 19), -1.35187935829163),
#  (464, datetime.date(2011, 11, 26), -3.13878583908081),
#  (465, datetime.date(2011, 12, 3), -5.29389810562134),
#  (466, datetime.date(2011, 12, 10), -6.54608821868896),
#  (467, datetime.date(2011, 12, 17), -8.65298175811768),
#  (468, datetime.date(2011, 12, 24), -9.1696834564209),
#  (469, datetime.date(2012, 1, 1), -8.22239303588867),
#  (470, datetime.date(2012, 1, 8), -9.60054683685303),
#  (471, datetime.date(2012, 1, 15), -8.56786918640137),
#  (472, datetime.date(2012, 1, 22), -8.57370758056641),
#  (473, datetime.date(2012, 1, 29), -10.1667366027832),
#  (474, datetime.date(2012, 2, 5), -11.9801626205444),
#  (475, datetime.date(2012, 2, 12), -13.1510620117188),
#  (476, datetime.date(2012, 2, 19), -12.7581634521484),
#  (477, datetime.date(2012, 2, 26), -11.0930023193359),
#  (478, datetime.date(2012, 3, 4), -12.046181678772),
#  (479, datetime.date(2012, 3, 11), -12.1600351333618),
#  (480, datetime.date(2012, 3, 18), -11.7473773956299),
#  (481, datetime.date(2012, 3, 25), -11.0741405487061),
#  (482, datetime.date(2012, 4, 1), -11.9552793502808),
#  (483, datetime.date(2012, 4, 8), -12.4058694839478),
#  (484, datetime.date(2012, 4, 15), -11.6257133483887),
#  (485, datetime.date(2012, 4, 22), -6.6278247833252),
#  (486, datetime.date(2012, 4, 29), -2.40225696563721),
#  (487, datetime.date(2012, 5, 6), -3.32922863960266),
#  (488, datetime.date(2012, 5, 13), -2.93366050720215),
#  (489, datetime.date(2012, 5, 20), -2.99587726593018),
#  (490, datetime.date(2012, 5, 27), -1.67036831378937),
#  (491, datetime.date(2012, 6, 3), -0.641076266765594),
#  (492, datetime.date(2012, 6, 10), -0.795541942119598),
#  (493, datetime.date(2012, 6, 17), -0.0638651102781296),
#  (494, datetime.date(2012, 6, 24), -0.748304486274719),
#  (495, datetime.date(2012, 7, 1), -1.55058670043945),
#  (496, datetime.date(2012, 7, 8), -1.53338587284088),
#  (497, datetime.date(2012, 7, 15), -2.23827266693115),
#  (498, datetime.date(2012, 7, 22), -2.64163517951965),
#  (499, datetime.date(2012, 7, 29), -1.49656820297241),
#  (500, datetime.date(2012, 8, 5), -2.75448966026306),
#  (501, datetime.date(2012, 8, 12), -4.00702857971191),
#  (502, datetime.date(2012, 8, 19), -5.38649034500122),
#  (503, datetime.date(2012, 8, 26), -6.67242670059204),
#  (504, datetime.date(2012, 9, 2), -8.08207607269287),
#  (505, datetime.date(2012, 9, 9), -8.27079677581787),
#  (506, datetime.date(2012, 9, 16), -8.16385173797607),
#  (507, datetime.date(2012, 9, 23), -7.81615161895752),
#  (508, datetime.date(2012, 9, 30), -7.44504737854004),
#  (509, datetime.date(2012, 10, 7), -7.12946653366089),
#  (510, datetime.date(2012, 10, 14), -7.88118648529053),
#  (511, datetime.date(2012, 10, 21), -4.89723873138428),
#  (512, datetime.date(2012, 10, 28), -2.57987141609192),
#  (513, datetime.date(2012, 11, 4), -3.7532114982605),
#  (514, datetime.date(2012, 11, 11), -5.35886716842651),
#  (515, datetime.date(2012, 11, 18), -7.23158979415894),
#  (516, datetime.date(2012, 11, 25), -7.47462606430054),
#  (517, datetime.date(2012, 12, 2), -8.59652996063232),
#  (518, datetime.date(2012, 12, 9), -8.75588130950928),
#  (519, datetime.date(2012, 12, 16), -8.17982006072998),
#  (520, datetime.date(2012, 12, 23), -7.44031953811646),
#  (521, datetime.date(2013, 1, 1), -4.23361682891846),
#  (522, datetime.date(2013, 1, 8), -2.12492370605469),
#  (523, datetime.date(2013, 1, 15), -4.39931106567383),
#  (524, datetime.date(2013, 1, 22), -6.71340465545654),
#  (525, datetime.date(2013, 1, 29), -8.56080532073975),
#  (526, datetime.date(2013, 2, 5), -3.62266182899475),
#  (527, datetime.date(2013, 2, 12), -0.368821382522583),
#  (528, datetime.date(2013, 2, 19), -0.461050659418106),
#  (529, datetime.date(2013, 2, 26), -1.6822202205658),
#  (530, datetime.date(2013, 3, 5), -1.63603258132935),
#  (531, datetime.date(2013, 3, 12), -0.033382635563612),
#  (532, datetime.date(2013, 3, 19), 0.0797130763530731),
#  (533, datetime.date(2013, 3, 26), -1.19630789756775),
#  (534, datetime.date(2013, 4, 2), -1.52530920505524),
#  (535, datetime.date(2013, 4, 9), -1.49876523017883),
#  (536, datetime.date(2013, 4, 16), -2.26743507385254),
#  (537, datetime.date(2013, 4, 23), -3.56047654151917),
#  (538, datetime.date(2013, 4, 30), -4.14396476745605),
#  (539, datetime.date(2013, 5, 7), -3.75128984451294),
#  (540, datetime.date(2013, 5, 14), -0.720739901065826),
#  (541, datetime.date(2013, 5, 21), -0.108067743480206),
#  (542, datetime.date(2013, 5, 28), 0.395586043596268),
#  (543, datetime.date(2013, 6, 4), -0.110586233437061),
#  (544, datetime.date(2013, 6, 11), -0.474329978227615),
#  (545, datetime.date(2013, 6, 18), 0.808094441890717),
#  (546, datetime.date(2013, 6, 25), 0.969321548938751),
#  (547, datetime.date(2013, 7, 2), 0.3977952003479),
#  (548, datetime.date(2013, 7, 9), -0.328810542821884),
#  (549, datetime.date(2013, 7, 16), -0.288556158542633),
#  (550, datetime.date(2013, 7, 23), 0.437428504228592),
#  (551, datetime.date(2013, 7, 30), -0.577668368816376),
#  (552, datetime.date(2013, 8, 6), -1.61527574062347),
#  (553, datetime.date(2013, 8, 13), -2.71017742156982),
#  (554, datetime.date(2013, 8, 20), -3.57758474349976),
#  (555, datetime.date(2013, 8, 27), -3.63303780555725),
#  (556, datetime.date(2013, 9, 3), -3.81670713424683),
#  (557, datetime.date(2013, 9, 10), -5.1145396232605),
#  (558, datetime.date(2013, 9, 17), -4.22652435302734),
#  (559, datetime.date(2013, 9, 24), -3.70131468772888),
#  (560, datetime.date(2013, 10, 1), -1.42019522190094),
#  (561, datetime.date(2013, 10, 8), -2.20849180221558),
#  (562, datetime.date(2013, 10, 15), -1.77039897441864),
#  (563, datetime.date(2013, 10, 22), -1.10600280761719),
#  (564, datetime.date(2013, 10, 29), -2.41189980506897),
#  (565, datetime.date(2013, 11, 5), -3.430903673172),
#  (566, datetime.date(2013, 11, 12), -4.52820920944214),
#  (567, datetime.date(2013, 11, 19), -4.22163343429565),
#  (568, datetime.date(2013, 11, 26), -4.31799125671387),
#  (569, datetime.date(2013, 12, 3), -3.87623500823975),
#  (570, datetime.date(2013, 12, 10), -3.69766855239868),
#  (571, datetime.date(2013, 12, 17), -5.81652069091797),
#  (572, datetime.date(2013, 12, 24), -7.52987480163574),
#  (573, datetime.date(2014, 1, 1), -5.7256555557251),
#  (574, datetime.date(2014, 1, 8), -5.1331582069397),
#  (575, datetime.date(2014, 1, 15), -4.13243627548218),
#  (576, datetime.date(2014, 1, 22), -5.95538091659546),
#  (577, datetime.date(2014, 1, 29), -7.77266025543213),
#  (578, datetime.date(2014, 2, 5), -9.9523286819458),
#  (579, datetime.date(2014, 2, 12), -11.191556930542),
#  (580, datetime.date(2014, 2, 19), -11.3215360641479),
#  (581, datetime.date(2014, 2, 26), -9.79621410369873),
#  (582, datetime.date(2014, 3, 5), -8.84023094177246),
#  (583, datetime.date(2014, 3, 12), -8.97147274017334),
#  (584, datetime.date(2014, 3, 19), -5.91244029998779),
#  (585, datetime.date(2014, 3, 26), -6.28472089767456),
#  (586, datetime.date(2014, 4, 2), -6.29577159881592),
#  (587, datetime.date(2014, 4, 9), -4.67146110534668),
#  (588, datetime.date(2014, 4, 16), -2.53902983665466),
#  (589, datetime.date(2014, 4, 23), -2.22696137428284),
#  (590, datetime.date(2014, 4, 30), -1.82028901576996),
#  (591, datetime.date(2014, 5, 7), -2.78222227096558),
#  (592, datetime.date(2014, 5, 14), -2.4390869140625),
#  (593, datetime.date(2014, 5, 21), -1.26424384117126),
#  (594, datetime.date(2014, 5, 28), -0.494848102331161),
#  (595, datetime.date(2014, 6, 4), 0.430460035800934),
#  (596, datetime.date(2014, 6, 11), 0.497514188289642),
#  (597, datetime.date(2014, 6, 18), 0.294563978910446),
#  (598, datetime.date(2014, 6, 25), 0.0429977066814899),
#  (599, datetime.date(2014, 7, 2), -0.264735251665115),
#  (600, datetime.date(2014, 7, 9), -0.397440582513809),
#  (601, datetime.date(2014, 7, 16), -0.349952220916748),
#  (602, datetime.date(2014, 7, 23), 0.288813352584839),
#  (603, datetime.date(2014, 7, 30), -0.675399839878082),
#  (604, datetime.date(2014, 8, 6), -1.8020213842392),
#  (605, datetime.date(2014, 8, 13), -1.64458906650543),
#  (606, datetime.date(2014, 8, 20), -2.59081244468689),
#  (607, datetime.date(2014, 8, 27), -3.41475987434387),
#  (608, datetime.date(2014, 9, 3), -2.38112759590149),
#  (609, datetime.date(2014, 9, 10), -3.27213883399963),
#  (610, datetime.date(2014, 9, 17), -2.24654912948608),
#  (611, datetime.date(2014, 9, 24), 0.235644996166229),
#  (612, datetime.date(2014, 10, 1), -0.128559082746506),
#  (613, datetime.date(2014, 10, 8), -2.02171206474304),
#  (614, datetime.date(2014, 10, 15), -3.87807893753052),
#  (615, datetime.date(2014, 10, 22), -5.18508911132812),
#  (616, datetime.date(2014, 10, 29), -4.46096038818359),
#  (617, datetime.date(2014, 11, 5), -2.67227840423584),
#  (618, datetime.date(2014, 11, 12), -4.02388334274292),
#  (619, datetime.date(2014, 11, 19), -4.49203491210938),
#  (620, datetime.date(2014, 11, 26), -3.80381512641907),
#  (621, datetime.date(2014, 12, 3), -5.2420129776001),
#  (622, datetime.date(2014, 12, 10), -5.83085489273071),
#  (623, datetime.date(2014, 12, 17), -6.11122751235962),
#  (624, datetime.date(2014, 12, 24), -4.96180105209351),
#  (625, datetime.date(2015, 1, 1), -3.24504685401917),
#  (626, datetime.date(2015, 1, 8), -3.72989249229431),
#  (627, datetime.date(2015, 1, 15), -4.73978662490845),
#  (628, datetime.date(2015, 1, 22), -5.1487193107605),
#  (629, datetime.date(2015, 1, 29), -3.66125273704529),
#  (630, datetime.date(2015, 2, 5), -3.83729600906372),
#  (631, datetime.date(2015, 2, 12), -2.56931018829346),
#  (632, datetime.date(2015, 2, 19), -1.49228870868683),
#  (633, datetime.date(2015, 2, 26), -1.61563384532928),
#  (634, datetime.date(2015, 3, 5), -1.32984387874603),
#  (635, datetime.date(2015, 3, 12), -2.59865045547485),
#  (636, datetime.date(2015, 3, 19), -3.78133630752563),
#  (637, datetime.date(2015, 3, 26), -2.60753583908081),
#  (638, datetime.date(2015, 4, 2), -3.33267760276794),
#  (639, datetime.date(2015, 4, 9), -4.47900390625),
#  (640, datetime.date(2015, 4, 16), -3.80760264396667),
#  (641, datetime.date(2015, 4, 23), -3.02693700790405),
#  (642, datetime.date(2015, 4, 30), -3.28449749946594),
#  (643, datetime.date(2015, 5, 7), -2.39607286453247),
#  (644, datetime.date(2015, 5, 14), -2.44734382629395),
#  (645, datetime.date(2015, 5, 21), -2.06885695457458),
#  (646, datetime.date(2015, 5, 28), -0.828046023845673),
#  (647, datetime.date(2015, 6, 4), -1.51470911502838),
#  (648, datetime.date(2015, 6, 11), -1.20265293121338),
#  (649, datetime.date(2015, 6, 18), -1.10368657112122),
#  (650, datetime.date(2015, 6, 25), -1.86142265796661),
#  (651, datetime.date(2015, 7, 2), 0.0172574892640114),
#  (652, datetime.date(2015, 7, 9), 0.911649584770203),
#  (653, datetime.date(2015, 7, 16), 0.857804119586945),
#  (654, datetime.date(2015, 7, 23), 0.329425811767578),
#  (655, datetime.date(2015, 7, 30), -0.628654360771179),
#  (656, datetime.date(2015, 8, 6), -1.63392817974091),
#  (657, datetime.date(2015, 8, 13), -2.45786595344543),
#  (658, datetime.date(2015, 8, 20), -2.60351920127869),
#  (659, datetime.date(2015, 8, 27), -2.01233959197998),
#  (660, datetime.date(2015, 9, 3), -2.57271528244019),
#  (661, datetime.date(2015, 9, 10), -0.843023002147675),
#  (662, datetime.date(2015, 9, 17), -2.27821040153503),
#  (663, datetime.date(2015, 9, 24), -1.26422679424286),
#  (664, datetime.date(2015, 10, 1), 0.0378681719303131),
#  (665, datetime.date(2015, 10, 8), 0.36542996764183),
#  (666, datetime.date(2015, 10, 15), 0.20253199338913),
#  (667, datetime.date(2015, 10, 22), -0.222383722662926),
#  (668, datetime.date(2015, 10, 29), -0.102458380162716),
#  (669, datetime.date(2015, 11, 5), 0.0957130268216133),
#  (670, datetime.date(2015, 11, 12), 0.0508941635489464),
#  (671, datetime.date(2015, 11, 19), 0.886040925979614),
#  (672, datetime.date(2015, 11, 26), 1.0293048620224),
#  (673, datetime.date(2015, 12, 3), 0.813294589519501),
#  (674, datetime.date(2015, 12, 10), 0.966444969177246),
#  (675, datetime.date(2015, 12, 17), 0.547106981277466),
#  (676, datetime.date(2015, 12, 24), 0.641869366168976),
#  (677, datetime.date(2016, 1, 1), 0.399120211601257),
#  (678, datetime.date(2016, 1, 8), 0.416418373584747),
#  (679, datetime.date(2016, 1, 15), -1.09229481220245),
#  (680, datetime.date(2016, 1, 22), -2.81918621063232),
#  (681, datetime.date(2016, 1, 29), -1.76163065433502),
#  (682, datetime.date(2016, 2, 5), -0.994161486625671),
#  (683, datetime.date(2016, 2, 12), -0.920470178127289),
#  (684, datetime.date(2016, 2, 19), -0.283088058233261),
#  (685, datetime.date(2016, 2, 26), -0.193455204367638),
#  (686, datetime.date(2016, 3, 4), -1.24977099895477),
#  (687, datetime.date(2016, 3, 11), -1.8363254070282),
#  (688, datetime.date(2016, 3, 18), -3.09979057312012),
#  (689, datetime.date(2016, 3, 25), -1.73403680324554),
#  (690, datetime.date(2016, 4, 1), -3.31317520141602),
#  (691, datetime.date(2016, 4, 8), -4.44069051742554),
#  (692, datetime.date(2016, 4, 15), -5.4917893409729),
#  (693, datetime.date(2016, 4, 22), -4.60714244842529),
#  (694, datetime.date(2016, 4, 29), -3.72944903373718),
#  (695, datetime.date(2016, 5, 6), -1.44380664825439),
#  (696, datetime.date(2016, 5, 13), 0.0510987602174282),
#  (697, datetime.date(2016, 5, 20), 0.232293516397476),
#  (698, datetime.date(2016, 5, 27), 0.501874029636383),
#  (699, datetime.date(2016, 6, 3), 0.0931969732046127),
#  (700, datetime.date(2016, 6, 10), -0.601830244064331),
#  (701, datetime.date(2016, 6, 17), 0.178562521934509),
#  (702, datetime.date(2016, 6, 24), 0.20988529920578),
#  (703, datetime.date(2016, 7, 1), -0.582301020622253),
#  (704, datetime.date(2016, 7, 8), -0.735181033611298),
#  (705, datetime.date(2016, 7, 15), 0.336947172880173),
#  (706, datetime.date(2016, 7, 22), -0.572516918182373),
#  (707, datetime.date(2016, 7, 29), -1.65842854976654),
#  (708, datetime.date(2016, 8, 5), -1.45391952991486),
#  (709, datetime.date(2016, 8, 12), -0.614639461040497),
#  (710, datetime.date(2016, 8, 19), 0.549856841564178),
#  (711, datetime.date(2016, 8, 26), -0.113202147185802),
#  (712, datetime.date(2016, 9, 2), -0.065743014216423),
#  (713, datetime.date(2016, 9, 9), -1.03570687770844),
#  (714, datetime.date(2016, 9, 16), -1.73219060897827),
#  (715, datetime.date(2016, 9, 23), -2.79124164581299),
#  (716, datetime.date(2016, 9, 30), -3.08090686798096),
#  (717, datetime.date(2016, 10, 7), -3.05382204055786),
#  (718, datetime.date(2016, 10, 14), -0.626666843891144),
#  (719, datetime.date(2016, 10, 21), -0.879986822605133),
#  (720, datetime.date(2016, 10, 28), -0.464816212654114),
#  (721, datetime.date(2016, 11, 4), -1.64286947250366),
#  (722, datetime.date(2016, 11, 11), -2.45577621459961),
#  (723, datetime.date(2016, 11, 18), -4.40405082702637),
#  (724, datetime.date(2016, 11, 25), -3.97456574440002),
#  (725, datetime.date(2016, 12, 2), -3.87365818023682),
#  (726, datetime.date(2016, 12, 9), -3.0103964805603),
#  (727, datetime.date(2016, 12, 16), -3.06784176826477),
#  (728, datetime.date(2016, 12, 23), -3.57998871803284),
#  (729, datetime.date(2017, 1, 1), -3.79187059402466),
#  (730, datetime.date(2017, 1, 8), -4.68672800064087)]

# %% [markdown]
# ### extract data

# %%
# %%time
SQL = ("""
SELECT
    geocodig_m , sigla, nome_munic, acquisition,
    (St_SummaryStats(St_Union(ST_Clip(rast,1,geom, true)))).*
INTO consultas_br.ndvi_f2_big_sul_crop
FROM modis_sul_250.ndvi_f2 , public.big_sul_crop
WHERE st_intersects(rast,geom)
GROUP BY geocodig_m , sigla, nome_munic, acquisition
ORDER BY acquisition;
COMMENT ON TABLE consultas_br.ndvi_f2_big_sul_crop
IS 'MOD NDVI for part of RS, SC, PR and part of SP';
""")
# %sql $SQL
# Out:
# (psycopg2.ProgrammingError) relation "modis_sul_250.ndvi_f2" does not exist
# LINE 5: FROM modis_sul_250.ndvi_f2 , public.big_sul_crop
#              ^
#  [SQL: 'SELECT\n    geocodig_m , sigla, nome_munic, acquisition,\n    (St_SummaryStats(St_Union(ST_Clip(rast,1,geom, true)))).*\nINTO consultas_br.ndvi_f2_big_sul_crop\nFROM modis_sul_250.ndvi_f2 , public.big_sul_crop\nWHERE st_intersects(rast,geom)\nGROUP BY geocodig_m , sigla, nome_munic, acquisition\nORDER BY acquisition;']
# CPU times: user 3.23 ms, sys: 0 ns, total: 3.23 ms
# Wall time: 2.6 ms

# %% [markdown]
# ** Polygon based **

# %%
dates = [('2007-10-29'),('2008-01-09')]

# %% [raw]
# #POLYGON BASED TEST
# SQL = ("""SELECT
#     id_2 , name_1, name_2, acquisition,
#     (St_SummaryStats(St_Union(ST_Clip(rast,1,geom, true)))).*
# FROM %s.%s , public.usa_adm2
# WHERE st_intersects(rast,geom)
#     AND acquisition BETWEEN '%s' AND '%s'
#     AND name_1 IN ('Nebraska','Illinois')
# GROUP BY id_2 , name_1, name_2, acquisition
# ORDER BY acquisition;
# """
#        %(schema,table,dates[0],dates[1]))
# print(SQL)
# %sql $SQL

# %%
#POLYGON BASED TEST - BRASIL
SQL = ("""SELECT 
    geocodig_m , sigla, nome_munic, acquisition,
    (St_SummaryStats(St_Union(ST_Clip(rast,1,geom, true)))).*
FROM %s.%s , public.big_sul_crop
WHERE st_intersects(rast,geom)
    AND acquisition BETWEEN '%s' AND '%s'
    AND sigla IN ('PR')
GROUP BY geocodig_m , sigla, nome_munic, acquisition
ORDER BY acquisition;
"""
       %(schema,table,dates[0],dates[1]))
print(SQL)
# %sql $SQL
# Out:
# SELECT
#     geocodig_m , sigla, nome_munic, acquisition,
#     (St_SummaryStats(St_Union(ST_Clip(rast,1,geom, true)))).*
# FROM GLEAM.swdi_root , public.big_sul_crop
# WHERE st_intersects(rast,geom)
#     AND acquisition BETWEEN '2007-10-29' AND '2008-01-09'
#     AND sigla IN ('PR')
# GROUP BY geocodig_m , sigla, nome_munic, acquisition
# ORDER BY acquisition;
#
# 3135 rows affected.
# [(4100103.0, 'PR', 'Abati', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4100707.0, 'PR', 'Alto Piquiri', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4100806.0, 'PR', 'Alvorada do Sul', datetime.date(2007, 10, 29), 1, -9.06481456756592, -9.06481456756592, 0.0, -9.06481456756592, -9.06481456756592),
#  (4101002.0, 'PR', 'Ampre', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4101051.0, 'PR', 'Anahy', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4101101.0, 'PR', 'Andir', datetime.date(2007, 10, 29), 1, -8.11718654632568, -8.11718654632568, 0.0, -8.11718654632568, -8.11718654632568),
#  (4101150.0, 'PR', 'ngulo', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4101408.0, 'PR', 'Apucarana', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4101507.0, 'PR', 'Arapongas', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4101606.0, 'PR', 'Arapoti', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4101655.0, 'PR', 'Arapu', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4101705.0, 'PR', 'Araruna', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4101853.0, 'PR', 'Ariranha do Iva', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4101903.0, 'PR', 'Assa', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4102000.0, 'PR', 'Assis Chateaubriand', datetime.date(2007, 10, 29), 2, -13.8046083450317, -6.90230417251587, 0.812844276428223, -7.71514844894409, -6.08945989608765),
#  (4102109.0, 'PR', 'Astorga', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4102208.0, 'PR', 'Atalaia', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4102406.0, 'PR', 'Bandeirantes', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4102505.0, 'PR', 'Barbosa Ferraz', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4102604.0, 'PR', 'Barraco', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4102703.0, 'PR', 'Barra do Jacar', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4102752.0, 'PR', 'Bela Vista da Caroba', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4102802.0, 'PR', 'Bela Vista do Paraso', datetime.date(2007, 10, 29), 1, -9.86413097381592, -9.86413097381592, 0.0, -9.86413097381592, -9.86413097381592),
#  (4103008.0, 'PR', 'Boa Esperana', datetime.date(2007, 10, 29), 1, -8.95015621185303, -8.95015621185303, 0.0, -8.95015621185303, -8.95015621185303),
#  (4103024.0, 'PR', 'Boa Esperana do Iguau', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4103040.0, 'PR', 'Boa Ventura de So Roque', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4103206.0, 'PR', 'Bom Sucesso', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4103222.0, 'PR', 'Bom Sucesso do Sul', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4103305.0, 'PR', 'Borrazpolis', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4103354.0, 'PR', 'Braganey', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4103370.0, 'PR', 'Brasilndia do Sul', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4103453.0, 'PR', 'Cafelndia', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4103479.0, 'PR', 'Cafezal do Sul', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4103503.0, 'PR', 'Califrnia', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4103602.0, 'PR', 'Cambar', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4103701.0, 'PR', 'Camb', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4103800.0, 'PR', 'Cambira', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4103909.0, 'PR', 'Campina da Lagoa', datetime.date(2007, 10, 29), 1, -4.63226366043091, -4.63226366043091, 0.0, -4.63226366043091, -4.63226366043091),
#  (4103958.0, 'PR', 'Campina do Simo', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4104055.0, 'PR', 'Campo Bonito', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4104105.0, 'PR', 'Campo do Tenente', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4104303.0, 'PR', 'Campo Mouro', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4104402.0, 'PR', 'Cndido de Abreu', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4104428.0, 'PR', 'Candi', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4104451.0, 'PR', 'Cantagalo', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4104501.0, 'PR', 'Capanema', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4104659.0, 'PR', 'Carambe', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4104808.0, 'PR', 'Cascavel', datetime.date(2007, 10, 29), 1, -6.55291509628296, -6.55291509628296, 0.0, -6.55291509628296, -6.55291509628296),
#  (4104907.0, 'PR', 'Castro', datetime.date(2007, 10, 29), 1, -10.3413858413696, -10.3413858413696, 0.0, -10.3413858413696, -10.3413858413696),
#  (4105003.0, 'PR', 'Catanduvas', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4105102.0, 'PR', 'Centenrio do Sul', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4105300.0, 'PR', 'Cu Azul', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4105409.0, 'PR', 'Chopinzinho', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4105508.0, 'PR', 'Cianorte', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4105706.0, 'PR', 'Clevelndia', datetime.date(2007, 10, 29), 1, -0.200459241867065, -0.200459241867065, 0.0, -0.200459241867065, -0.200459241867065),
#  (4105904.0, 'PR', 'Colorado', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4106001.0, 'PR', 'Congonhinhas', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4106100.0, 'PR', 'Conselheiro Mairinck', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4106308.0, 'PR', 'Corblia', datetime.date(2007, 10, 29), 1, -6.42823886871338, -6.42823886871338, 0.0, -6.42823886871338, -6.42823886871338),
#  (4106407.0, 'PR', 'Cornlio Procpio', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4106456.0, 'PR', 'Coronel Domingos Soares', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4106506.0, 'PR', 'Coronel Vivida', datetime.date(2007, 10, 29), 1, -1.85033488273621, -1.85033488273621, 0.0, -1.85033488273621, -1.85033488273621),
#  (4106555.0, 'PR', 'Corumbata do Sul', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4106571.0, 'PR', 'Cruzeiro do Iguau', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4106605.0, 'PR', 'Cruzeiro do Oeste', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4106704.0, 'PR', 'Cruzeiro do Sul', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4106852.0, 'PR', 'Cruzmaltina', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4107009.0, 'PR', 'Curiva', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4107157.0, 'PR', "Diamante D'Oeste", datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4107207.0, 'PR', 'Dois Vizinhos', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4107306.0, 'PR', 'Doutor Camargo', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4107405.0, 'PR', 'Enas Marques', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4107504.0, 'PR', 'Engenheiro Beltro', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4107546.0, 'PR', 'Espigo Alto do Iguau', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4107553.0, 'PR', 'Farol', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4107603.0, 'PR', 'Faxinal', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4107702.0, 'PR', 'Fnix', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4107736.0, 'PR', 'Fernandes Pinheiro', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4107751.0, 'PR', 'Figueira', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4107801.0, 'PR', 'Flora', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4107850.0, 'PR', 'Flor da Serra do Sul', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4107900.0, 'PR', 'Floresta', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4108007.0, 'PR', 'Florestpolis', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4108106.0, 'PR', 'Flrida', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4108205.0, 'PR', 'Formosa do Oeste', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4108304.0, 'PR', 'Foz do Iguau', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4108320.0, 'PR', 'Francisco Alves', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4108403.0, 'PR', 'Francisco Beltro', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4108452.0, 'PR', 'Foz do Jordo', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4108551.0, 'PR', 'Godoy Moreira', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4108601.0, 'PR', 'Goioer', datetime.date(2007, 10, 29), 1, -8.70013904571533, -8.70013904571533, 0.0, -8.70013904571533, -8.70013904571533),
#  (4108650.0, 'PR', 'Goioxim', datetime.date(2007, 10, 29), 1, -4.61875534057617, -4.61875534057617, 0.0, -4.61875534057617, -4.61875534057617),
#  (4108700.0, 'PR', 'Grandes Rios', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4108809.0, 'PR', 'Guara', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4108957.0, 'PR', 'Guamiranga', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4109203.0, 'PR', 'Guaraci', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4109302.0, 'PR', 'Guaraniau', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4109401.0, 'PR', 'Guarapuava', datetime.date(2007, 10, 29), 2, -7.38691449165344, -3.69345724582672, 0.430573344230652, -4.12403059005737, -3.26288390159607),
#  (4109658.0, 'PR', 'Honrio Serpa', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4109708.0, 'PR', 'Ibaiti', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4109757.0, 'PR', 'Ibema', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4109807.0, 'PR', 'Ibipor', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4110003.0, 'PR', 'Iguarau', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4110052.0, 'PR', 'Iguatu', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4110078.0, 'PR', 'Imba', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4110102.0, 'PR', 'Imbituva', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4110409.0, 'PR', 'Indianpolis', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4110508.0, 'PR', 'Ipiranga', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4110607.0, 'PR', 'Ipor', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4110656.0, 'PR', 'Iracema do Oeste', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4110706.0, 'PR', 'Irati', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4110805.0, 'PR', 'Iretama', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4111001.0, 'PR', 'Itambarac', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4111100.0, 'PR', 'Itamb', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4111209.0, 'PR', "Itapejara d'Oeste", datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4111407.0, 'PR', 'Iva', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4111506.0, 'PR', 'Ivaipor', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4111605.0, 'PR', 'Ivatuba', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4111704.0, 'PR', 'Jaboti', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4111902.0, 'PR', 'Jaguapit', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4112009.0, 'PR', 'Jaguariava', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4112108.0, 'PR', 'Jandaia do Sul', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4112207.0, 'PR', 'Janipolis', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4112306.0, 'PR', 'Japira', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4112405.0, 'PR', 'Japur', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4112504.0, 'PR', 'Jardim Alegre', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4112702.0, 'PR', 'Jataizinho', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4112751.0, 'PR', 'Jesutas', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4112900.0, 'PR', 'Jundia do Sul', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4112959.0, 'PR', 'Juranda', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4113007.0, 'PR', 'Jussara', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4113106.0, 'PR', 'Kalor', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4113205.0, 'PR', 'Lapa', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4113304.0, 'PR', 'Laranjeiras do Sul', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4113403.0, 'PR', 'Lepolis', datetime.date(2007, 10, 29), 1, -8.42300224304199, -8.42300224304199, 0.0, -8.42300224304199, -8.42300224304199),
#  (4113429.0, 'PR', 'Lidianpolis', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4113452.0, 'PR', 'Lindoeste', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4113601.0, 'PR', 'Lobato', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4113700.0, 'PR', 'Londrina', datetime.date(2007, 10, 29), 3, -23.9801716804504, -7.99339056015015, 0.56970716508793, -8.59331512451172, -7.22768449783325),
#  (4113734.0, 'PR', 'Luiziana', datetime.date(2007, 10, 29), 2, -11.8416836261749, -5.92084181308746, 2.41913831233978, -8.33998012542725, -3.50170350074768),
#  (4113759.0, 'PR', 'Lunardelli', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4113809.0, 'PR', 'Lupionpolis', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4114005.0, 'PR', 'Mambor', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4114104.0, 'PR', 'Mandaguau', datetime.date(2007, 10, 29), 1, -5.61927938461304, -5.61927938461304, 0.0, -5.61927938461304, -5.61927938461304),
#  (4114203.0, 'PR', 'Mandaguari', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4114401.0, 'PR', 'Mangueirinha', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4114500.0, 'PR', 'Manoel Ribas', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4114609.0, 'PR', 'Marechal Cndido Rondon', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4114807.0, 'PR', 'Marialva', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4114906.0, 'PR', 'Marilndia do Sul', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4115101.0, 'PR', 'Mariluz', datetime.date(2007, 10, 29), 1, -6.04124927520752, -6.04124927520752, 0.0, -6.04124927520752, -6.04124927520752),
#  (4115200.0, 'PR', 'Maring', datetime.date(2007, 10, 29), 1, -5.77466535568237, -5.77466535568237, 0.0, -5.77466535568237, -5.77466535568237),
#  (4115309.0, 'PR', 'Maripolis', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4115358.0, 'PR', 'Marip', datetime.date(2007, 10, 29), 1, -5.25113916397095, -5.25113916397095, 0.0, -5.25113916397095, -5.25113916397095),
#  (4115408.0, 'PR', 'Marmeleiro', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4115507.0, 'PR', 'Marumbi', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4115606.0, 'PR', 'Matelndia', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4115739.0, 'PR', 'Mato Rico', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4115754.0, 'PR', 'Mau da Serra', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4115804.0, 'PR', 'Medianeira', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4115853.0, 'PR', 'Mercedes', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4116109.0, 'PR', 'Moreira Sales', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4116307.0, 'PR', 'Munhoz de Melo', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4116406.0, 'PR', 'Nossa Senhora das Graas', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4116604.0, 'PR', 'Nova Amrica da Colina', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4116703.0, 'PR', 'Nova Aurora', datetime.date(2007, 10, 29), 1, -5.50822639465332, -5.50822639465332, 0.0, -5.50822639465332, -5.50822639465332),
#  (4116802.0, 'PR', 'Nova Cantu', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4116901.0, 'PR', 'Nova Esperana', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4117008.0, 'PR', 'Nova Ftima', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4117057.0, 'PR', 'Nova Laranjeiras', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4117214.0, 'PR', 'Nova Santa Brbara', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4117222.0, 'PR', 'Nova Santa Rosa', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4117255.0, 'PR', 'Nova Prata do Iguau', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4117271.0, 'PR', 'Nova Tebas', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4117305.0, 'PR', 'Ortigueira', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4117404.0, 'PR', 'Ourizona', datetime.date(2007, 10, 29), 1, -5.55561113357544, -5.55561113357544, 0.0, -5.55561113357544, -5.55561113357544),
#  (4117453.0, 'PR', 'Ouro Verde do Oeste', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4117503.0, 'PR', 'Paiandu', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4117602.0, 'PR', 'Palmas', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4117701.0, 'PR', 'Palmeira', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4117800.0, 'PR', 'Palmital', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4117909.0, 'PR', 'Palotina', datetime.date(2007, 10, 29), 1, -7.45732688903809, -7.45732688903809, 0.0, -7.45732688903809, -7.45732688903809),
#  (4118451.0, 'PR', 'Pato Bragado', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4118501.0, 'PR', 'Pato Branco', datetime.date(2007, 10, 29), 1, -0.451447129249573, -0.451447129249573, 0.0, -0.451447129249573, -0.451447129249573),
#  (4118600.0, 'PR', 'Paula Freitas', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4118709.0, 'PR', 'Paulo Frontin', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4118808.0, 'PR', 'Peabiru', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4118857.0, 'PR', 'Perobal', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4119004.0, 'PR', "Prola d'Oeste", datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4119103.0, 'PR', 'Pin', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4119202.0, 'PR', 'Pinhalo', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4119301.0, 'PR', 'Pinho', datetime.date(2007, 10, 29), 1, -3.92662000656128, -3.92662000656128, 0.0, -3.92662000656128, -3.92662000656128),
#  (4119400.0, 'PR', 'Pira do Sul', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4119608.0, 'PR', 'Pitanga', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4119657.0, 'PR', 'Pitangueiras', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4119806.0, 'PR', 'Planalto', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4119905.0, 'PR', 'Ponta Grossa', datetime.date(2007, 10, 29), 1, -8.28033638000488, -8.28033638000488, 0.0, -8.28033638000488, -8.28033638000488),
#  (4120002.0, 'PR', 'Porecatu', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4120101.0, 'PR', 'Porto Amazonas', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4120150.0, 'PR', 'Porto Barreiro', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4120333.0, 'PR', 'Prado Ferreira', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4120358.0, 'PR', 'Pranchita', datetime.date(2007, 10, 29), 1, -1.12978672981262, -1.12978672981262, 0.0, -1.12978672981262, -1.12978672981262),
#  (4120408.0, 'PR', 'Presidente Castelo Branco', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4120507.0, 'PR', 'Primeiro de Maio', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4120606.0, 'PR', 'Prudentpolis', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4120655.0, 'PR', 'Quarto Centenrio', datetime.date(2007, 10, 29), 1, -4.82390689849854, -4.82390689849854, 0.0, -4.82390689849854, -4.82390689849854),
#  (4120853.0, 'PR', 'Quatro Pontes', datetime.date(2007, 10, 29), 1, -5.02602577209473, -5.02602577209473, 0.0, -5.02602577209473, -5.02602577209473),
#  (4120903.0, 'PR', 'Quedas do Iguau', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4121109.0, 'PR', 'Quinta do Sol', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4121257.0, 'PR', 'Ramilndia', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4121307.0, 'PR', 'Rancho Alegre', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4121356.0, 'PR', "Rancho Alegre D'Oeste", datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4121406.0, 'PR', 'Realeza', datetime.date(2007, 10, 29), 1, -1.73876810073853, -1.73876810073853, 0.0, -1.73876810073853, -1.73876810073853),
#  (4121505.0, 'PR', 'Rebouas', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4121604.0, 'PR', 'Renascena', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4121703.0, 'PR', 'Reserva', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4121752.0, 'PR', 'Reserva do Iguau', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4121901.0, 'PR', 'Ribeiro do Pinhal', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4122008.0, 'PR', 'Rio Azul', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4122107.0, 'PR', 'Rio Bom', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4122156.0, 'PR', 'Rio Bonito do Iguau', datetime.date(2007, 10, 29), 1, -2.70720386505127, -2.70720386505127, 0.0, -2.70720386505127, -2.70720386505127),
#  (4122172.0, 'PR', 'Rio Branco do Iva', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4122404.0, 'PR', 'Rolndia', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4122503.0, 'PR', 'Roncador', datetime.date(2007, 10, 29), 1, -6.01965761184692, -6.01965761184692, 0.0, -6.01965761184692, -6.01965761184692),
#  (4122701.0, 'PR', 'Sabudia', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4123006.0, 'PR', 'Salto do Lontra', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4123105.0, 'PR', 'Santa Amlia', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4123204.0, 'PR', 'Santa Ceclia do Pavo', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4123402.0, 'PR', 'Santa F', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4123501.0, 'PR', 'Santa Helena', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4123808.0, 'PR', 'Santa Izabel do Oeste', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4123857.0, 'PR', 'Santa Maria do Oeste', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4123907.0, 'PR', 'Santa Mariana', datetime.date(2007, 10, 29), 1, -7.71708917617798, -7.71708917617798, 0.0, -7.71708917617798, -7.71708917617798),
#  (4124004.0, 'PR', 'Santana do Itarar', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4124020.0, 'PR', 'Santa Tereza do Oeste', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4124053.0, 'PR', 'Santa Terezinha de Itaipu', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4124103.0, 'PR', 'Santo Antnio da Platina', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4124301.0, 'PR', 'Santo Antnio do Paraso', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4124400.0, 'PR', 'Santo Antnio do Sudoeste', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4124509.0, 'PR', 'Santo Incio', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4124608.0, 'PR', 'So Carlos do Iva', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4124707.0, 'PR', 'So Jernimo da Serra', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4124806.0, 'PR', 'So Joo', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4125001.0, 'PR', 'So Joo do Iva', datetime.date(2007, 10, 29), 1, -5.7960524559021, -5.7960524559021, 0.0, -5.7960524559021, -5.7960524559021),
#  (4125100.0, 'PR', 'So Joo do Triunfo', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4125209.0, 'PR', "So Jorge d'Oeste", datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4125308.0, 'PR', 'So Jorge do Iva', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4125407.0, 'PR', 'So Jos da Boa Vista', datetime.date(2007, 10, 29), 1, -8.85712909698486, -8.85712909698486, 0.0, -8.85712909698486, -8.85712909698486),
#  (4125555.0, 'PR', 'So Manoel do Paran', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4125605.0, 'PR', 'So Mateus do Sul', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4125704.0, 'PR', 'So Miguel do Iguau', datetime.date(2007, 10, 29), 2, -6.22875189781189, -3.11437594890594, 0.294488549232483, -3.40886449813843, -2.81988739967346),
#  (4125753.0, 'PR', 'So Pedro do Iguau', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4125803.0, 'PR', 'So Pedro do Iva', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4126009.0, 'PR', 'So Sebastio da Amoreira', datetime.date(2007, 10, 29), 1, -8.97593212127686, -8.97593212127686, 0.0, -8.97593212127686, -8.97593212127686),
#  (4126108.0, 'PR', 'So Tom', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4126207.0, 'PR', 'Sapopema', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4126256.0, 'PR', 'Sarandi', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4126272.0, 'PR', 'Saudade do Iguau', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4126306.0, 'PR', 'Sengs', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4126355.0, 'PR', 'Serranpolis do Iguau', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4126405.0, 'PR', 'Sertaneja', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4126504.0, 'PR', 'Sertanpolis', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4126652.0, 'PR', 'Sulina', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4126678.0, 'PR', 'Tamarana', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4127007.0, 'PR', 'Teixeira Soares', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4127106.0, 'PR', 'Telmaco Borba', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4127205.0, 'PR', 'Terra Boa', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4127403.0, 'PR', 'Terra Roxa', datetime.date(2007, 10, 29), 1, -6.68175363540649, -6.68175363540649, 0.0, -6.68175363540649, -6.68175363540649),
#  (4127502.0, 'PR', 'Tibagi', datetime.date(2007, 10, 29), 2, -18.3823003768921, -9.19115018844604, 0.512630939483643, -9.70378112792969, -8.6785192489624),
#  (4127700.0, 'PR', 'Toledo', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4127809.0, 'PR', 'Tomazina', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4127908.0, 'PR', 'Tuneiras do Oeste', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4127957.0, 'PR', 'Tupssi', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4127965.0, 'PR', 'Turvo', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4128005.0, 'PR', 'Ubirat', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4128104.0, 'PR', 'Umuarama', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4128203.0, 'PR', 'Unio da Vitria', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4128302.0, 'PR', 'Uniflor', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4128401.0, 'PR', 'Ura', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4128500.0, 'PR', 'Wenceslau Braz', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4128534.0, 'PR', 'Ventania', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4128559.0, 'PR', 'Vera Cruz do Oeste', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4128609.0, 'PR', 'Ver', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4128658.0, 'PR', 'Virmond', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4128708.0, 'PR', 'Vitorino', datetime.date(2007, 10, 29), 0, None, None, None, None, None),
#  (4100103.0, 'PR', 'Abati', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4100707.0, 'PR', 'Alto Piquiri', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4100806.0, 'PR', 'Alvorada do Sul', datetime.date(2007, 11, 5), 1, -6.25010824203491, -6.25010824203491, 0.0, -6.25010824203491, -6.25010824203491),
#  (4101002.0, 'PR', 'Ampre', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4101051.0, 'PR', 'Anahy', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4101101.0, 'PR', 'Andir', datetime.date(2007, 11, 5), 1, -6.07429838180542, -6.07429838180542, 0.0, -6.07429838180542, -6.07429838180542),
#  (4101150.0, 'PR', 'ngulo', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4101408.0, 'PR', 'Apucarana', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4101507.0, 'PR', 'Arapongas', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4101606.0, 'PR', 'Arapoti', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4101655.0, 'PR', 'Arapu', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4101705.0, 'PR', 'Araruna', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4101853.0, 'PR', 'Ariranha do Iva', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4101903.0, 'PR', 'Assa', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4102000.0, 'PR', 'Assis Chateaubriand', datetime.date(2007, 11, 5), 2, -11.9194803237915, -5.95974016189575, 0.628318786621094, -6.58805894851685, -5.33142137527466),
#  (4102109.0, 'PR', 'Astorga', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4102208.0, 'PR', 'Atalaia', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4102406.0, 'PR', 'Bandeirantes', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4102505.0, 'PR', 'Barbosa Ferraz', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4102604.0, 'PR', 'Barraco', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4102703.0, 'PR', 'Barra do Jacar', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4102752.0, 'PR', 'Bela Vista da Caroba', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4102802.0, 'PR', 'Bela Vista do Paraso', datetime.date(2007, 11, 5), 1, -6.894944190979, -6.894944190979, 0.0, -6.894944190979, -6.894944190979),
#  (4103008.0, 'PR', 'Boa Esperana', datetime.date(2007, 11, 5), 1, -7.72882413864136, -7.72882413864136, 0.0, -7.72882413864136, -7.72882413864136),
#  (4103024.0, 'PR', 'Boa Esperana do Iguau', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4103040.0, 'PR', 'Boa Ventura de So Roque', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4103206.0, 'PR', 'Bom Sucesso', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4103222.0, 'PR', 'Bom Sucesso do Sul', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4103305.0, 'PR', 'Borrazpolis', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4103354.0, 'PR', 'Braganey', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4103370.0, 'PR', 'Brasilndia do Sul', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4103453.0, 'PR', 'Cafelndia', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4103479.0, 'PR', 'Cafezal do Sul', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4103503.0, 'PR', 'Califrnia', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4103602.0, 'PR', 'Cambar', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4103701.0, 'PR', 'Camb', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4103800.0, 'PR', 'Cambira', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4103909.0, 'PR', 'Campina da Lagoa', datetime.date(2007, 11, 5), 1, -3.52487683296204, -3.52487683296204, 0.0, -3.52487683296204, -3.52487683296204),
#  (4103958.0, 'PR', 'Campina do Simo', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4104055.0, 'PR', 'Campo Bonito', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4104105.0, 'PR', 'Campo do Tenente', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4104303.0, 'PR', 'Campo Mouro', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4104402.0, 'PR', 'Cndido de Abreu', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4104428.0, 'PR', 'Candi', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4104451.0, 'PR', 'Cantagalo', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4104501.0, 'PR', 'Capanema', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4104659.0, 'PR', 'Carambe', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4104808.0, 'PR', 'Cascavel', datetime.date(2007, 11, 5), 1, -5.55377960205078, -5.55377960205078, 0.0, -5.55377960205078, -5.55377960205078),
#  (4104907.0, 'PR', 'Castro', datetime.date(2007, 11, 5), 1, -9.14152526855469, -9.14152526855469, 0.0, -9.14152526855469, -9.14152526855469),
#  (4105003.0, 'PR', 'Catanduvas', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4105102.0, 'PR', 'Centenrio do Sul', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4105300.0, 'PR', 'Cu Azul', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4105409.0, 'PR', 'Chopinzinho', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4105508.0, 'PR', 'Cianorte', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4105706.0, 'PR', 'Clevelndia', datetime.date(2007, 11, 5), 1, -0.340714544057846, -0.340714544057846, 0.0, -0.340714544057846, -0.340714544057846),
#  (4105904.0, 'PR', 'Colorado', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4106001.0, 'PR', 'Congonhinhas', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4106100.0, 'PR', 'Conselheiro Mairinck', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4106308.0, 'PR', 'Corblia', datetime.date(2007, 11, 5), 1, -5.2075023651123, -5.2075023651123, 0.0, -5.2075023651123, -5.2075023651123),
#  (4106407.0, 'PR', 'Cornlio Procpio', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4106456.0, 'PR', 'Coronel Domingos Soares', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4106506.0, 'PR', 'Coronel Vivida', datetime.date(2007, 11, 5), 1, -1.68433225154877, -1.68433225154877, 0.0, -1.68433225154877, -1.68433225154877),
#  (4106555.0, 'PR', 'Corumbata do Sul', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4106571.0, 'PR', 'Cruzeiro do Iguau', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4106605.0, 'PR', 'Cruzeiro do Oeste', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4106704.0, 'PR', 'Cruzeiro do Sul', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4106852.0, 'PR', 'Cruzmaltina', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4107009.0, 'PR', 'Curiva', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4107157.0, 'PR', "Diamante D'Oeste", datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4107207.0, 'PR', 'Dois Vizinhos', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4107306.0, 'PR', 'Doutor Camargo', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4107405.0, 'PR', 'Enas Marques', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4107504.0, 'PR', 'Engenheiro Beltro', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4107546.0, 'PR', 'Espigo Alto do Iguau', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4107553.0, 'PR', 'Farol', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4107603.0, 'PR', 'Faxinal', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4107702.0, 'PR', 'Fnix', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4107736.0, 'PR', 'Fernandes Pinheiro', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4107751.0, 'PR', 'Figueira', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4107801.0, 'PR', 'Flora', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4107850.0, 'PR', 'Flor da Serra do Sul', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4107900.0, 'PR', 'Floresta', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4108007.0, 'PR', 'Florestpolis', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4108106.0, 'PR', 'Flrida', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4108205.0, 'PR', 'Formosa do Oeste', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4108304.0, 'PR', 'Foz do Iguau', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4108320.0, 'PR', 'Francisco Alves', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4108403.0, 'PR', 'Francisco Beltro', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4108452.0, 'PR', 'Foz do Jordo', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4108551.0, 'PR', 'Godoy Moreira', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4108601.0, 'PR', 'Goioer', datetime.date(2007, 11, 5), 1, -7.70941591262817, -7.70941591262817, 0.0, -7.70941591262817, -7.70941591262817),
#  (4108650.0, 'PR', 'Goioxim', datetime.date(2007, 11, 5), 1, -4.15956020355225, -4.15956020355225, 0.0, -4.15956020355225, -4.15956020355225),
#  (4108700.0, 'PR', 'Grandes Rios', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4108809.0, 'PR', 'Guara', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4108957.0, 'PR', 'Guamiranga', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4109203.0, 'PR', 'Guaraci', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4109302.0, 'PR', 'Guaraniau', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4109401.0, 'PR', 'Guarapuava', datetime.date(2007, 11, 5), 2, -6.03319048881531, -3.01659524440765, 0.1285480260849, -3.14514327049255, -2.88804721832275),
#  (4109658.0, 'PR', 'Honrio Serpa', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4109708.0, 'PR', 'Ibaiti', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4109757.0, 'PR', 'Ibema', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4109807.0, 'PR', 'Ibipor', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4110003.0, 'PR', 'Iguarau', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4110052.0, 'PR', 'Iguatu', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4110078.0, 'PR', 'Imba', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4110102.0, 'PR', 'Imbituva', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4110409.0, 'PR', 'Indianpolis', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4110508.0, 'PR', 'Ipiranga', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4110607.0, 'PR', 'Ipor', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4110656.0, 'PR', 'Iracema do Oeste', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4110706.0, 'PR', 'Irati', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4110805.0, 'PR', 'Iretama', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4111001.0, 'PR', 'Itambarac', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4111100.0, 'PR', 'Itamb', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4111209.0, 'PR', "Itapejara d'Oeste", datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4111407.0, 'PR', 'Iva', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4111506.0, 'PR', 'Ivaipor', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4111605.0, 'PR', 'Ivatuba', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4111704.0, 'PR', 'Jaboti', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4111902.0, 'PR', 'Jaguapit', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4112009.0, 'PR', 'Jaguariava', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4112108.0, 'PR', 'Jandaia do Sul', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4112207.0, 'PR', 'Janipolis', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4112306.0, 'PR', 'Japira', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4112405.0, 'PR', 'Japur', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4112504.0, 'PR', 'Jardim Alegre', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4112702.0, 'PR', 'Jataizinho', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4112751.0, 'PR', 'Jesutas', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4112900.0, 'PR', 'Jundia do Sul', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4112959.0, 'PR', 'Juranda', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4113007.0, 'PR', 'Jussara', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4113106.0, 'PR', 'Kalor', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4113205.0, 'PR', 'Lapa', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4113304.0, 'PR', 'Laranjeiras do Sul', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4113403.0, 'PR', 'Lepolis', datetime.date(2007, 11, 5), 1, -4.83350467681885, -4.83350467681885, 0.0, -4.83350467681885, -4.83350467681885),
#  (4113429.0, 'PR', 'Lidianpolis', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4113452.0, 'PR', 'Lindoeste', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4113601.0, 'PR', 'Lobato', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4113700.0, 'PR', 'Londrina', datetime.date(2007, 11, 5), 3, -17.7912321090698, -5.93041070302327, 0.835645819668803, -6.79598236083984, -4.80081415176392),
#  (4113734.0, 'PR', 'Luiziana', datetime.date(2007, 11, 5), 2, -8.74288535118103, -4.37144267559052, 2.27030003070831, -6.64174270629883, -2.1011426448822),
#  (4113759.0, 'PR', 'Lunardelli', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4113809.0, 'PR', 'Lupionpolis', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4114005.0, 'PR', 'Mambor', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4114104.0, 'PR', 'Mandaguau', datetime.date(2007, 11, 5), 1, -3.42738723754883, -3.42738723754883, 0.0, -3.42738723754883, -3.42738723754883),
#  (4114203.0, 'PR', 'Mandaguari', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4114401.0, 'PR', 'Mangueirinha', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4114500.0, 'PR', 'Manoel Ribas', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4114609.0, 'PR', 'Marechal Cndido Rondon', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4114807.0, 'PR', 'Marialva', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4114906.0, 'PR', 'Marilndia do Sul', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4115101.0, 'PR', 'Mariluz', datetime.date(2007, 11, 5), 1, -4.36717462539673, -4.36717462539673, 0.0, -4.36717462539673, -4.36717462539673),
#  (4115200.0, 'PR', 'Maring', datetime.date(2007, 11, 5), 1, -3.73103070259094, -3.73103070259094, 0.0, -3.73103070259094, -3.73103070259094),
#  (4115309.0, 'PR', 'Maripolis', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4115358.0, 'PR', 'Marip', datetime.date(2007, 11, 5), 1, -4.28671455383301, -4.28671455383301, 0.0, -4.28671455383301, -4.28671455383301),
#  (4115408.0, 'PR', 'Marmeleiro', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4115507.0, 'PR', 'Marumbi', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4115606.0, 'PR', 'Matelndia', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4115739.0, 'PR', 'Mato Rico', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4115754.0, 'PR', 'Mau da Serra', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4115804.0, 'PR', 'Medianeira', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4115853.0, 'PR', 'Mercedes', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4116109.0, 'PR', 'Moreira Sales', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4116307.0, 'PR', 'Munhoz de Melo', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4116406.0, 'PR', 'Nossa Senhora das Graas', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4116604.0, 'PR', 'Nova Amrica da Colina', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4116703.0, 'PR', 'Nova Aurora', datetime.date(2007, 11, 5), 1, -4.61103820800781, -4.61103820800781, 0.0, -4.61103820800781, -4.61103820800781),
#  (4116802.0, 'PR', 'Nova Cantu', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4116901.0, 'PR', 'Nova Esperana', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4117008.0, 'PR', 'Nova Ftima', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4117057.0, 'PR', 'Nova Laranjeiras', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4117214.0, 'PR', 'Nova Santa Brbara', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4117222.0, 'PR', 'Nova Santa Rosa', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4117255.0, 'PR', 'Nova Prata do Iguau', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
#  (4117271.0, 'PR', 'Nova Tebas', datetime.date(2007, 11, 5), 0, None, None, None, None, None),
# ...
#  (4128005.0, 'PR', 'Ubirat', datetime.date(2007, 11, 12), 0, None, None, None, None, None),
#  (4128104.0, 'PR', 'Umuarama', datetime.date(2007, 11, 12), 0, None, None, None, None, None),
#  (4128203.0, 'PR', 'Unio da Vitria', datetime.date(2007, 11, 12), 0, None, None, None, None, None),
#  (4128302.0, 'PR', 'Uniflor', datetime.date(2007, 11, 12), 0, None, None, None, None, None),
#  (4128401.0, 'PR', 'Ura', datetime.date(2007, 11, 12), 0, None, None, None, None, None),
#  (4128500.0, 'PR', 'Wenceslau Braz', datetime.date(2007, 11, 12), 0, None, None, None, None, None),
#  (4128534.0, 'PR', 'Ventania', datetime.date(2007, 11, 12), 0, None, None, None, None, None),
#  (4128559.0, 'PR', 'Vera Cruz do Oeste', datetime.date(2007, 11, 12), 0, None, None, None, None, None),
#  (4128609.0, 'PR', 'Ver', datetime.date(2007, 11, 12), 0, None, None, None, None, None),
#  (4128658.0, 'PR', 'Virmond', datetime.date(2007, 11, 12), 0, None, None, None, None, None),
#  (4128708.0, 'PR', 'Vitorino', datetime.date(2007, 11, 12), 0, None, None, None, None, None),
#  (4100103.0, 'PR', 'Abati', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4100707.0, 'PR', 'Alto Piquiri', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4100806.0, 'PR', 'Alvorada do Sul', datetime.date(2007, 11, 19), 1, -5.25793170928955, -5.25793170928955, 0.0, -5.25793170928955, -5.25793170928955),
#  (4101002.0, 'PR', 'Ampre', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4101051.0, 'PR', 'Anahy', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4101101.0, 'PR', 'Andir', datetime.date(2007, 11, 19), 1, -5.61983728408813, -5.61983728408813, 0.0, -5.61983728408813, -5.61983728408813),
#  (4101150.0, 'PR', 'ngulo', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4101408.0, 'PR', 'Apucarana', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4101507.0, 'PR', 'Arapongas', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4101606.0, 'PR', 'Arapoti', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4101655.0, 'PR', 'Arapu', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4101705.0, 'PR', 'Araruna', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4101853.0, 'PR', 'Ariranha do Iva', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4101903.0, 'PR', 'Assa', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4102000.0, 'PR', 'Assis Chateaubriand', datetime.date(2007, 11, 19), 2, -8.25598335266113, -4.12799167633057, 0.143123149871826, -4.27111482620239, -3.98486852645874),
#  (4102109.0, 'PR', 'Astorga', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4102208.0, 'PR', 'Atalaia', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4102406.0, 'PR', 'Bandeirantes', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4102505.0, 'PR', 'Barbosa Ferraz', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4102604.0, 'PR', 'Barraco', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4102703.0, 'PR', 'Barra do Jacar', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4102752.0, 'PR', 'Bela Vista da Caroba', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4102802.0, 'PR', 'Bela Vista do Paraso', datetime.date(2007, 11, 19), 1, -5.41441583633423, -5.41441583633423, 0.0, -5.41441583633423, -5.41441583633423),
#  (4103008.0, 'PR', 'Boa Esperana', datetime.date(2007, 11, 19), 1, -5.45788669586182, -5.45788669586182, 0.0, -5.45788669586182, -5.45788669586182),
#  (4103024.0, 'PR', 'Boa Esperana do Iguau', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4103040.0, 'PR', 'Boa Ventura de So Roque', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4103206.0, 'PR', 'Bom Sucesso', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4103222.0, 'PR', 'Bom Sucesso do Sul', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4103305.0, 'PR', 'Borrazpolis', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4103354.0, 'PR', 'Braganey', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4103370.0, 'PR', 'Brasilndia do Sul', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4103453.0, 'PR', 'Cafelndia', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4103479.0, 'PR', 'Cafezal do Sul', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4103503.0, 'PR', 'Califrnia', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4103602.0, 'PR', 'Cambar', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4103701.0, 'PR', 'Camb', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4103800.0, 'PR', 'Cambira', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4103909.0, 'PR', 'Campina da Lagoa', datetime.date(2007, 11, 19), 1, -2.77312994003296, -2.77312994003296, 0.0, -2.77312994003296, -2.77312994003296),
#  (4103958.0, 'PR', 'Campina do Simo', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4104055.0, 'PR', 'Campo Bonito', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4104105.0, 'PR', 'Campo do Tenente', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4104303.0, 'PR', 'Campo Mouro', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4104402.0, 'PR', 'Cndido de Abreu', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4104428.0, 'PR', 'Candi', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4104451.0, 'PR', 'Cantagalo', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4104501.0, 'PR', 'Capanema', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4104659.0, 'PR', 'Carambe', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4104808.0, 'PR', 'Cascavel', datetime.date(2007, 11, 19), 1, -3.99851608276367, -3.99851608276367, 0.0, -3.99851608276367, -3.99851608276367),
#  (4104907.0, 'PR', 'Castro', datetime.date(2007, 11, 19), 1, -7.85647487640381, -7.85647487640381, 0.0, -7.85647487640381, -7.85647487640381),
#  (4105003.0, 'PR', 'Catanduvas', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4105102.0, 'PR', 'Centenrio do Sul', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4105300.0, 'PR', 'Cu Azul', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4105409.0, 'PR', 'Chopinzinho', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4105508.0, 'PR', 'Cianorte', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4105706.0, 'PR', 'Clevelndia', datetime.date(2007, 11, 19), 1, -1.04677700996399, -1.04677700996399, 0.0, -1.04677700996399, -1.04677700996399),
#  (4105904.0, 'PR', 'Colorado', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4106001.0, 'PR', 'Congonhinhas', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4106100.0, 'PR', 'Conselheiro Mairinck', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4106308.0, 'PR', 'Corblia', datetime.date(2007, 11, 19), 1, -3.86070132255554, -3.86070132255554, 0.0, -3.86070132255554, -3.86070132255554),
#  (4106407.0, 'PR', 'Cornlio Procpio', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4106456.0, 'PR', 'Coronel Domingos Soares', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4106506.0, 'PR', 'Coronel Vivida', datetime.date(2007, 11, 19), 1, -1.95341324806213, -1.95341324806213, 0.0, -1.95341324806213, -1.95341324806213),
#  (4106555.0, 'PR', 'Corumbata do Sul', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4106571.0, 'PR', 'Cruzeiro do Iguau', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4106605.0, 'PR', 'Cruzeiro do Oeste', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4106704.0, 'PR', 'Cruzeiro do Sul', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4106852.0, 'PR', 'Cruzmaltina', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4107009.0, 'PR', 'Curiva', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4107157.0, 'PR', "Diamante D'Oeste", datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4107207.0, 'PR', 'Dois Vizinhos', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4107306.0, 'PR', 'Doutor Camargo', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4107405.0, 'PR', 'Enas Marques', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4107504.0, 'PR', 'Engenheiro Beltro', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4107546.0, 'PR', 'Espigo Alto do Iguau', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4107553.0, 'PR', 'Farol', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4107603.0, 'PR', 'Faxinal', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4107702.0, 'PR', 'Fnix', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4107736.0, 'PR', 'Fernandes Pinheiro', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4107751.0, 'PR', 'Figueira', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4107801.0, 'PR', 'Flora', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4107850.0, 'PR', 'Flor da Serra do Sul', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4107900.0, 'PR', 'Floresta', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4108007.0, 'PR', 'Florestpolis', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4108106.0, 'PR', 'Flrida', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4108205.0, 'PR', 'Formosa do Oeste', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4108304.0, 'PR', 'Foz do Iguau', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4108320.0, 'PR', 'Francisco Alves', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4108403.0, 'PR', 'Francisco Beltro', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4108452.0, 'PR', 'Foz do Jordo', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4108551.0, 'PR', 'Godoy Moreira', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4108601.0, 'PR', 'Goioer', datetime.date(2007, 11, 19), 1, -6.19399213790894, -6.19399213790894, 0.0, -6.19399213790894, -6.19399213790894),
#  (4108650.0, 'PR', 'Goioxim', datetime.date(2007, 11, 19), 1, -4.18543863296509, -4.18543863296509, 0.0, -4.18543863296509, -4.18543863296509),
#  (4108700.0, 'PR', 'Grandes Rios', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4108809.0, 'PR', 'Guara', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4108957.0, 'PR', 'Guamiranga', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4109203.0, 'PR', 'Guaraci', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4109302.0, 'PR', 'Guaraniau', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4109401.0, 'PR', 'Guarapuava', datetime.date(2007, 11, 19), 2, -6.27418279647827, -3.13709139823914, 0.265842914581299, -3.40293431282043, -2.87124848365784),
#  (4109658.0, 'PR', 'Honrio Serpa', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4109708.0, 'PR', 'Ibaiti', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4109757.0, 'PR', 'Ibema', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4109807.0, 'PR', 'Ibipor', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4110003.0, 'PR', 'Iguarau', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4110052.0, 'PR', 'Iguatu', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4110078.0, 'PR', 'Imba', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4110102.0, 'PR', 'Imbituva', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4110409.0, 'PR', 'Indianpolis', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4110508.0, 'PR', 'Ipiranga', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4110607.0, 'PR', 'Ipor', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4110656.0, 'PR', 'Iracema do Oeste', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4110706.0, 'PR', 'Irati', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4110805.0, 'PR', 'Iretama', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4111001.0, 'PR', 'Itambarac', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4111100.0, 'PR', 'Itamb', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4111209.0, 'PR', "Itapejara d'Oeste", datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4111407.0, 'PR', 'Iva', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4111506.0, 'PR', 'Ivaipor', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4111605.0, 'PR', 'Ivatuba', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4111704.0, 'PR', 'Jaboti', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4111902.0, 'PR', 'Jaguapit', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4112009.0, 'PR', 'Jaguariava', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4112108.0, 'PR', 'Jandaia do Sul', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4112207.0, 'PR', 'Janipolis', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4112306.0, 'PR', 'Japira', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4112405.0, 'PR', 'Japur', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4112504.0, 'PR', 'Jardim Alegre', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4112702.0, 'PR', 'Jataizinho', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4112751.0, 'PR', 'Jesutas', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4112900.0, 'PR', 'Jundia do Sul', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4112959.0, 'PR', 'Juranda', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4113007.0, 'PR', 'Jussara', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4113106.0, 'PR', 'Kalor', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4113205.0, 'PR', 'Lapa', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4113304.0, 'PR', 'Laranjeiras do Sul', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4113403.0, 'PR', 'Lepolis', datetime.date(2007, 11, 19), 1, -4.06904363632202, -4.06904363632202, 0.0, -4.06904363632202, -4.06904363632202),
#  (4113429.0, 'PR', 'Lidianpolis', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4113452.0, 'PR', 'Lindoeste', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4113601.0, 'PR', 'Lobato', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4113700.0, 'PR', 'Londrina', datetime.date(2007, 11, 19), 3, -14.3308734893799, -4.77695782979329, 0.551559319676229, -5.34941911697388, -4.03187799453735),
#  (4113734.0, 'PR', 'Luiziana', datetime.date(2007, 11, 19), 2, -6.77152490615845, -3.38576245307922, 1.38068985939026, -4.76645231246948, -2.00507259368896),
#  (4113759.0, 'PR', 'Lunardelli', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4113809.0, 'PR', 'Lupionpolis', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4114005.0, 'PR', 'Mambor', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  (4114104.0, 'PR', 'Mandaguau', datetime.date(2007, 11, 19), 1, -3.78825902938843, -3.78825902938843, 0.0, -3.78825902938843, -3.78825902938843),
#  (4114203.0, 'PR', 'Mandaguari', datetime.date(2007, 11, 19), 0, None, None, None, None, None),
#  ...]

# %% [raw]
# result = %sql $SQL
#
# result = result.DataFrame()
#
# result.to_csv("teste3.csv")

# %%
result = %sql $SQL
result = result.DataFrame()

# %%
result.sigla.unique()

# %%
result[(result.sigla == 'PB') & (result['count'] == 0)]

# %% [markdown]
# ### Getting results into tables

# %%
# the st_buffer(geom,0) prevents some topology errors
SQL = ("""
SELECT
    geocodig_m , sigla, nome_munic, acquisition,
    (St_SummaryStats(St_Union(ST_Clip(rast,1,st_buffer(geom, 0), true)))).*
INTO consultas_br.sul_chirps_zscore
FROM chirps.zscore_dec , public.big_sul
WHERE st_intersects(rast,geom)
--    AND acquisition BETWEEN '2007-10-29' AND '2007-11-19'
    AND sigla IN ('PR','SC','RS')
GROUP BY geocodig_m , sigla, nome_munic, acquisition
ORDER BY acquisition;
""")
# %sql $SQL
# Out:
# 734184 rows affected.
# []

# %%
xuleta.shemale()
# Out:
# To:denismeia@icloud.com
# From: denismeia@gmail.com
# Subject:PROCESS DONE
#
# done!

# %%
dates = [('2002-07-01'),('2018-03-09')]
l1 = ["modis_lai","modis_et"]
l2 = ["lai","et"]
for i,j in zip(l1,l2):
    SQL = ("""SELECT 
    geocodig_m , sigla, nome_munic, acquisition,
    (St_SummaryStats(St_Union(ST_Clip(rast,1,geom, true)))).*
    INTO consultas_br.%s
    FROM %s.%s , public.big_sul_crop
    WHERE st_intersects(rast,geom)
    AND acquisition BETWEEN '%s' AND '%s'
    AND sigla IN ('PR','RS','SC')
    GROUP BY geocodig_m , sigla, nome_munic, acquisition
    ORDER BY acquisition;
    """
       %(j,i,j,dates[0],dates[1]))
    print(SQL)
    # %sql $SQL
# Out:
# SELECT
#     geocodig_m , sigla, nome_munic, acquisition,
#     (St_SummaryStats(St_Union(ST_Clip(rast,1,geom, true)))).*
#     INTO consultas_br.lai
#     FROM modis_lai.lai , public.big_sul_crop
#     WHERE st_intersects(rast,geom)
#     AND acquisition BETWEEN '2002-07-01' AND '2018-03-09'
#     AND sigla IN ('PR','RS','SC')
#     GROUP BY geocodig_m , sigla, nome_munic, acquisition
#     ORDER BY acquisition;
#
# 403650 rows affected.
# SELECT
#     geocodig_m , sigla, nome_munic, acquisition,
#     (St_SummaryStats(St_Union(ST_Clip(rast,1,geom, true)))).*
#     INTO consultas_br.et
#     FROM modis_et.et , public.big_sul_crop
#     WHERE st_intersects(rast,geom)
#     AND acquisition BETWEEN '2002-07-01' AND '2018-03-09'
#     AND sigla IN ('PR','RS','SC')
#     GROUP BY geocodig_m , sigla, nome_munic, acquisition
#     ORDER BY acquisition;
#
# 378495 rows affected.

# %%
xu.shemale()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-9ea76634ecfd> in <module>()
# ----> 1 xu.shemale()
#
# NameError: name 'xu' is not defined
